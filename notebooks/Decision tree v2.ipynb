# %%
import pandas as pd

from sklearn.tree import DecisionTreeRegressor

import numpy as np

xl = pd.ExcelFile('../data/PCA_data.xlsx')
df = xl.parse('new')#,header=None)

#bikes = pd.read_csv('bikes.csv')
regressor = DecisionTreeRegressor(max_depth=2)
regressor.fit(df[['Amplitude', 'Duration','Accumulated dose']], df['DGR'])

DecisionTreeRegressor(criterion='mse', max_depth=2, max_features=None,

           max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,

           min_weight_fraction_leaf=0.0)#, presort=False, random_state=None)#,

           #splitter='best')
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
nx = 30

ny = 30

# creating a grid of points

x_amp = np.linspace(200, 2000, nx) # min amplitude 500, max 2000

y_dur = np.linspace(4, 168, ny) # min duration 4, max 168

xx, yy = np.meshgrid(x_amp, y_dur)

# evaluating the regressor on all the points

z_dgr = regressor.predict(np.array([xx.flatten(), yy.flatten()]).T)

zz = np.reshape(z_dgr, (nx, ny))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-de1c9dfe422c> in <module>
#      13 # evaluating the regressor on all the points
#      14
# ---> 15 z_dgr = regressor.predict(np.array([xx.flatten(), yy.flatten()]).T)
#      16
#      17 zz = np.reshape(z_dgr, (nx, ny))
#
# ~\Anaconda3new\lib\site-packages\sklearn\tree\_classes.py in predict(self, X, check_input)
#     435         """
#     436         check_is_fitted(self)
# --> 437         X = self._validate_X_predict(X, check_input)
#     438         proba = self.tree_.predict(X)
#     439         n_samples = X.shape[0]
#
# ~\Anaconda3new\lib\site-packages\sklearn\tree\_classes.py in _validate_X_predict(self, X, check_input)
#     401         if check_input:
#     402             X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr",
# --> 403                                     reset=False)
# ...

# %%
# import numpy package for arrays and stuff
import numpy as np 
  
# import matplotlib.pyplot for plotting our result
import matplotlib.pyplot as plt
  
# import pandas for importing csv files 
import pandas as pd

# %%
xl = pd.ExcelFile('../data/PCA_data.xlsx')
df = xl.parse('new')#,header=None)

print(df.head())
print(df.shape)
# Out:
#    Amplitude  Duration  Accumulated dose         N        DGR
# 0       1000       168              1000  2.609411  10.090759
# 1       1000       168              1000  2.979771   5.136975
# 2       1000       168              1000  2.865221   6.164093
# 3       2000         4              2000  1.999982 -15.801756
# 4       2000         4              2000  2.760342 -14.282713
# (42, 5)

# %%
df_no_missing_N = df.loc[(np.isnan(df.N) == False)].copy()

# %%
X1 = df.iloc[:,:-2]
X1

# X1 is missing one row - figure out why
# Out:
#     Amplitude  Duration  Accumulated dose
# 0        1000       168              1000
# 1        1000       168              1000
# 2        1000       168              1000
# 3        2000         4              2000
# 4        2000         4              2000
# 5        2000         4              2000
# 6         500         4               500
# 7         500         4               500
# 8         500         4               500
# 9        1000       168              1000
# 10       1000       168              1000
# 11       1000       168              1000
# 12       2000       168              2000
# 13       2000       168              2000
# 14       2000       168              2000
# 15        500       168              1000
# 16        500       168              1000
# 17        500       168              1000
# 18        500       168              1000
# 19        500       168              1000
# 20        500       168              1000
# ...

# %%
X2 = df_no_missing_N.iloc[:,:-2]
X2#.head()
# Out:
#     Amplitude  Duration  Accumulated dose
# 0        1000       168              1000
# 1        1000       168              1000
# 2        1000       168              1000
# 3        2000         4              2000
# 4        2000         4              2000
# 5        2000         4              2000
# 6         500         4               500
# 7         500         4               500
# 8         500         4               500
# 9        1000       168              1000
# 10       1000       168              1000
# 11       1000       168              1000
# 12       2000       168              2000
# 13       2000       168              2000
# 14       2000       168              2000
# 15        500       168              1000
# 16        500       168              1000
# 17        500       168              1000
# 18        500       168              1000
# 19        500       168              1000
# 20        500       168              1000
# ...

# %%
y1 = df['DGR'].copy()
y2 = df_no_missing_N['N'].copy()

# %%
# import the regressor
from sklearn.tree import DecisionTreeRegressor 
  
# create a regressor object
regressor = DecisionTreeRegressor(random_state = 0)
  
# fit the regressor with X and Y data
regressor.fit(X1, y1)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
# predicting a new value
  
# test the output by changing values, like 3750
y_pred = regressor.predict('1500')
  
# print the predicted price
print("Predicted price: % d\n"% y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-72a086f4c4a5> in <module>
#       2
#       3 # test the output by changing values, like 3750
# ----> 4 y_pred = regressor.predict('1500')
#       5
#       6 # print the predicted price
#
# ~\Anaconda3new\lib\site-packages\sklearn\tree\_classes.py in predict(self, X, check_input)
#     435         """
#     436         check_is_fitted(self)
# --> 437         X = self._validate_X_predict(X, check_input)
#     438         proba = self.tree_.predict(X)
#     439         n_samples = X.shape[0]
#
# ~\Anaconda3new\lib\site-packages\sklearn\tree\_classes.py in _validate_X_predict(self, X, check_input)
#     401         if check_input:
#     402             X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr",
# --> 403                                     reset=False)
# ...
