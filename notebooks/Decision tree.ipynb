# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# %%
xl = pd.ExcelFile('../data/PCA_data.xlsx')
df = xl.parse('new')#,header=None)

print(df.head())
print(df.shape)
# Out:
#    Amplitude  Duration  Accumulated dose         N        DGR
# 0       1000       168              1000  2.609411  10.090759
# 1       1000       168              1000  2.979771   5.136975
# 2       1000       168              1000  2.865221   6.164093
# 3       2000         4              2000  1.999982 -15.801756
# 4       2000         4              2000  2.760342 -14.282713
# (42, 5)

# %%
df.dtypes
# Out:
# Amplitude             int64
# Duration              int64
# Accumulated dose      int64
# N                   float64
# DGR                 float64
# dtype: object

# %%
df['Amplitude'].unique()
# Out:
# array([1000, 2000,  500,  200], dtype=int64)

# %%
df['Duration'].unique()
# Out:
# array([168,   4], dtype=int64)

# %%
df['Accumulated dose'].unique()
# Out:
# array([1000, 2000,  500, 1500], dtype=int64)

# %%
df['N'].unique()
# Out:
# array([2.60941124, 2.97977114, 2.86522079, 1.99998224, 2.76034188,
#        2.02693844, 2.17550278, 2.12057209, 1.13963091, 2.87504005,
#        3.13118458, 2.93488932, 3.76830077, 4.23490095, 3.91720724,
#        2.74445581, 3.35874772, 2.40742111, 2.3934567 , 2.25557375,
#        2.75702429, 2.57193875, 2.94725585, 2.03067064, 2.21811104,
#        2.73235106, 2.18040442, 2.63888049, 2.36608624,        nan,
#        3.49629664, 1.91922283, 3.15910721, 1.45922875, 1.83478403,
#        2.3710568 , 3.31671357, 2.26910806, 3.03569031, 1.61825013,
#        1.79612362, 1.91841853])

# %%
df['DGR'].unique()
# Out:
# array([ 10.09075937,   5.1369751 ,   6.16409341, -15.80175557,
#        -14.28271304,  -4.96772008,  -4.21029912,  -6.60111967,
#         -2.45999912,   6.36253373,  -0.28819403,   5.55504115,
#          8.05551088,   5.76040426,   7.50879956,  -1.18409955,
#         11.62953285,  13.18704143,  12.49508536,  13.05067071,
#         12.63552954,  11.48128541,  16.76895331,  15.96349639,
#         17.86473089,  16.6559142 ,  13.59034112,  14.1150525 ,
#         15.48771661,  16.99308128,  17.10418622,  16.1970621 ,
#         16.54221405,  14.87595436,  17.97101142,  13.9852281 ,
#         12.2109996 ,  12.35358121])

# %%
len(df.loc[(np.isnan(df.N) == True)])
# Out:
# 1

# %%
df.loc[(np.isnan(df.N) == True)]
# Out:
#     Amplitude  Duration  Accumulated dose   N        DGR
# 29        500       168              1000 NaN  13.187041

# %%
len(df)
# Out:
# 42

# %%
df_no_missing_N = df.loc[(np.isnan(df.N) == False)].copy()

# %%
df_no_missing_N
# Out:
#     Amplitude  Duration  Accumulated dose         N        DGR
# 0        1000       168              1000  2.609411  10.090759
# 1        1000       168              1000  2.979771   5.136975
# 2        1000       168              1000  2.865221   6.164093
# 3        2000         4              2000  1.999982 -15.801756
# 4        2000         4              2000  2.760342 -14.282713
# 5        2000         4              2000  2.026938  -4.967720
# 6         500         4               500  2.175503  -4.210299
# 7         500         4               500  2.120572  -6.601120
# 8         500         4               500  1.139631  -2.459999
# 9        1000       168              1000  2.875040   6.362534
# 10       1000       168              1000  3.131185   6.164093
# 11       1000       168              1000  2.934889  -0.288194
# 12       2000       168              2000  3.768301   5.555041
# 13       2000       168              2000  4.234901   8.055511
# 14       2000       168              2000  3.917207   5.760404
# 15        500       168              1000  2.744456   7.508800
# 16        500       168              1000  3.358748  -1.184100
# 17        500       168              1000  2.407421  11.629533
# 18        500       168              1000  2.393457  13.187041
# 19        500       168              1000  2.255574  12.495085
# 20        500       168              1000  2.757024  13.050671
# 21        500       168              1000  2.571939  12.635530
# 22        500       168              1000  2.947256  11.481285
# 23        500       168              1000  2.030671  16.768953
# 24       1000       168              1000  2.218111  15.963496
# 25       1000       168              1000  2.732351  17.864731
# 26       1000       168              1000  2.180404  16.655914
# 27        500       168              1000  2.638880  13.590341
# 28        500       168              1000  2.366086  14.115053
# 30        500       168              1500  3.496297  15.487717
# 31        500       168              1500  1.919223  14.115053
# 32        500       168              1500  3.159107  16.993081
# 33       1000       168              1000  1.459229  17.104186
# 34       1000       168              1000  1.834784  16.197062
# 35        500       168              1000  2.371057  16.542214
# 36        500       168              1000  3.316714  14.875954
# 37        500       168              1500  2.269108  17.971011
# 38        500       168              1500  3.035690  13.985228
# 39        200       168              1000  1.618250  14.115053
# 40        200       168              1000  1.796124  12.211000
# 41        200       168              1000  1.918419  12.353581

# %%
len(df_no_missing_N)
# Out:
# 41

# %%
len(df)
# Out:
# 42

# %%
X1 = df.iloc[:,:-2]
X1

# X1 is missing one row - figure out why
# Out:
#     Amplitude  Duration  Accumulated dose
# 0        1000       168              1000
# 1        1000       168              1000
# 2        1000       168              1000
# 3        2000         4              2000
# 4        2000         4              2000
# 5        2000         4              2000
# 6         500         4               500
# 7         500         4               500
# 8         500         4               500
# 9        1000       168              1000
# 10       1000       168              1000
# 11       1000       168              1000
# 12       2000       168              2000
# 13       2000       168              2000
# 14       2000       168              2000
# 15        500       168              1000
# 16        500       168              1000
# 17        500       168              1000
# 18        500       168              1000
# 19        500       168              1000
# 20        500       168              1000
# 21        500       168              1000
# 22        500       168              1000
# 23        500       168              1000
# 24       1000       168              1000
# 25       1000       168              1000
# 26       1000       168              1000
# 27        500       168              1000
# 28        500       168              1000
# 29        500       168              1000
# 30        500       168              1500
# 31        500       168              1500
# 32        500       168              1500
# 33       1000       168              1000
# 34       1000       168              1000
# 35        500       168              1000
# 36        500       168              1000
# 37        500       168              1500
# 38        500       168              1500
# 39        200       168              1000
# 40        200       168              1000
# 41        200       168              1000

# %%
X2 = df_no_missing_N.iloc[:,:-2]
X2#.head()
# Out:
#     Amplitude  Duration  Accumulated dose
# 0        1000       168              1000
# 1        1000       168              1000
# 2        1000       168              1000
# 3        2000         4              2000
# 4        2000         4              2000
# 5        2000         4              2000
# 6         500         4               500
# 7         500         4               500
# 8         500         4               500
# 9        1000       168              1000
# 10       1000       168              1000
# 11       1000       168              1000
# 12       2000       168              2000
# 13       2000       168              2000
# 14       2000       168              2000
# 15        500       168              1000
# 16        500       168              1000
# 17        500       168              1000
# 18        500       168              1000
# 19        500       168              1000
# 20        500       168              1000
# 21        500       168              1000
# 22        500       168              1000
# 23        500       168              1000
# 24       1000       168              1000
# 25       1000       168              1000
# 26       1000       168              1000
# 27        500       168              1000
# 28        500       168              1000
# 30        500       168              1500
# 31        500       168              1500
# 32        500       168              1500
# 33       1000       168              1000
# 34       1000       168              1000
# 35        500       168              1000
# 36        500       168              1000
# 37        500       168              1500
# 38        500       168              1500
# 39        200       168              1000
# 40        200       168              1000
# 41        200       168              1000

# %%
len(X2)
# Out:
# 41

# %%
y1 = df['DGR'].copy()
y2 = df_no_missing_N['N'].copy()

# %%
y1,y2
# Out:
# (0     10.090759
#  1      5.136975
#  2      6.164093
#  3    -15.801756
#  4    -14.282713
#  5     -4.967720
#  6     -4.210299
#  7     -6.601120
#  8     -2.459999
#  9      6.362534
#  10     6.164093
#  11    -0.288194
#  12     5.555041
#  13     8.055511
#  14     5.760404
#  15     7.508800
#  16    -1.184100
#  17    11.629533
#  18    13.187041
#  19    12.495085
#  20    13.050671
#  21    12.635530
#  22    11.481285
#  23    16.768953
#  24    15.963496
#  25    17.864731
#  26    16.655914
#  27    13.590341
#  28    14.115053
#  29    13.187041
#  30    15.487717
#  31    14.115053
#  32    16.993081
#  33    17.104186
#  34    16.197062
#  35    16.542214
#  36    14.875954
#  37    17.971011
#  38    13.985228
#  39    14.115053
#  40    12.211000
#  41    12.353581
#  Name: DGR, dtype: float64,
#  0     2.609411
#  1     2.979771
#  2     2.865221
#  3     1.999982
#  4     2.760342
#  5     2.026938
#  6     2.175503
#  7     2.120572
#  8     1.139631
#  9     2.875040
#  10    3.131185
#  11    2.934889
#  12    3.768301
#  13    4.234901
#  14    3.917207
#  15    2.744456
#  16    3.358748
#  17    2.407421
#  18    2.393457
#  19    2.255574
#  20    2.757024
#  21    2.571939
#  22    2.947256
#  23    2.030671
#  24    2.218111
#  25    2.732351
#  26    2.180404
#  27    2.638880
#  28    2.366086
#  30    3.496297
#  31    1.919223
#  32    3.159107
#  33    1.459229
#  34    1.834784
#  35    2.371057
#  36    3.316714
#  37    2.269108
#  38    3.035690
#  39    1.618250
#  40    1.796124
#  41    1.918419
#  Name: N, dtype: float64)

# %%
df
# Out:
#     Amplitude  Duration  Accumulated dose         N        DGR
# 0        1000       168              1000  2.609411  10.090759
# 1        1000       168              1000  2.979771   5.136975
# 2        1000       168              1000  2.865221   6.164093
# 3        2000         4              2000  1.999982 -15.801756
# 4        2000         4              2000  2.760342 -14.282713
# 5        2000         4              2000  2.026938  -4.967720
# 6         500         4               500  2.175503  -4.210299
# 7         500         4               500  2.120572  -6.601120
# 8         500         4               500  1.139631  -2.459999
# 9        1000       168              1000  2.875040   6.362534
# 10       1000       168              1000  3.131185   6.164093
# 11       1000       168              1000  2.934889  -0.288194
# 12       2000       168              2000  3.768301   5.555041
# 13       2000       168              2000  4.234901   8.055511
# 14       2000       168              2000  3.917207   5.760404
# 15        500       168              1000  2.744456   7.508800
# 16        500       168              1000  3.358748  -1.184100
# 17        500       168              1000  2.407421  11.629533
# 18        500       168              1000  2.393457  13.187041
# 19        500       168              1000  2.255574  12.495085
# 20        500       168              1000  2.757024  13.050671
# 21        500       168              1000  2.571939  12.635530
# 22        500       168              1000  2.947256  11.481285
# 23        500       168              1000  2.030671  16.768953
# 24       1000       168              1000  2.218111  15.963496
# 25       1000       168              1000  2.732351  17.864731
# 26       1000       168              1000  2.180404  16.655914
# 27        500       168              1000  2.638880  13.590341
# 28        500       168              1000  2.366086  14.115053
# 29        500       168              1000       NaN  13.187041
# 30        500       168              1500  3.496297  15.487717
# 31        500       168              1500  1.919223  14.115053
# 32        500       168              1500  3.159107  16.993081
# 33       1000       168              1000  1.459229  17.104186
# 34       1000       168              1000  1.834784  16.197062
# 35        500       168              1000  2.371057  16.542214
# 36        500       168              1000  3.316714  14.875954
# 37        500       168              1500  2.269108  17.971011
# 38        500       168              1500  3.035690  13.985228
# 39        200       168              1000  1.618250  14.115053
# 40        200       168              1000  1.796124  12.211000
# 41        200       168              1000  1.918419  12.353581

# %%
# data types

# Amplitude - cat / int
# Duration - cat / int 
# Accumulated dose / cat / int

X1.dtypes
# Out:
# Amplitude           int64
# Duration            int64
# Accumulated dose    int64
# dtype: object

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1,y1,random_state=42)
X2_train, X2_test, y2_train, y2_test = train_test_split(X2,y2,random_state=42)

clf_dt1 = DecisionTreeClassifier(random_state=42)
clf_dt1 = clf_dt1.fit(X1_train,y1_train)

clf_dt2 = DecisionTreeClassifier(random_state=42)
clf_dt2 = clf_dt2.fit(X2_train,y2_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-522fd85a5fee> in <module>
#       3
#       4 clf_dt1 = DecisionTreeClassifier(random_state=42)
# ----> 5 clf_dt1 = clf_dt1.fit(X1_train,y1_train)
#       6
#       7 clf_dt2 = DecisionTreeClassifier(random_state=42)
#
# ~\Anaconda3new\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     900             sample_weight=sample_weight,
#     901             check_input=check_input,
# --> 902             X_idx_sorted=X_idx_sorted)
#     903         return self
#     904
#
# ~\Anaconda3new\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     188
#     189         if is_classification:
# --> 190             check_classification_targets(y)
#     191             y = np.copy(y)
#     192
#
# ~\Anaconda3new\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     181     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     182                       'multilabel-indicator', 'multilabel-sequences']:
# --> 183         raise ValueError("Unknown label type: %r" % y_type)
#     184
#     185
#
# ValueError: Unknown label type: 'continuous'

# %%
X1_test

# %%
X1.dtypes
