# %%
# Code outline:
# 1. Indoor system - data:
#   a. Read data and parameters
#   b. process data (measurements)
# 2. Outdoor system - data:
#   a. Read data and parameters
#   b. Process data (measurements)
#   c. Build interpolations functions for temperature and light HOBO data
# 3. Offshore system - data:
#   a. Read data and parameters
#   b. Process data (measurements)
#   c. Build interpolations functions for temperature and light IMS data
# 4. Calculate model results for:
#   a. Indoor system
#   b. Outdoor system
#   c. Offshore system
# 5. Calculate errors in the combined df
# df_combined structure:
#System, time, m_exp, m_mod, m_SRE,Nint_exp, Nint_mod, Nint_SRE Next_exp, Next_mod, Next_SRE
# 6... minimize errors?

# %%
from __future__ import division
import numpy as np
import scipy as sp
from scipy.integrate import odeint
from scipy import stats
from scipy import interpolate
import math
import matplotlib.pyplot as plt
import pandas as pd # to read excel
print(f"pandas version is {pd.__version__}")
import seaborn as sns
from array import *
import researchpy as rp
import scipy.stats as stats
# %matplotlib inline

from myfunctions import *

import datetime
# Out:
# pandas version is 1.0.1

# %%
import sys
print(sys.version)
# Out:
# 3.7.3 (default, Apr 24 2019, 15:29:51) [MSC v.1915 64 bit (AMD64)]

# %%
# 1. Indoor system
#   a. Read data and parameters from excel file

xl = pd.ExcelFile('../data/Parameters.xlsx')
x2 = pd.ExcelFile('../data/Data.xlsx')

# Import parameters into df1
df1 = xl.parse('Parameters')

# assigmment of parameters to values: 
for key,val in zip(df1.Parameter,df1.Indoor_value):
    exec(key + '=val')
    print(key,val)

# Import indoor data into df2
df2 = x2.parse('Indoor')

df2.head()
# Out:
# umol_to_percent_DW 0.0014
# n_days 7.0
# Duration 7.0
# Nint0 1.85
# m0 0.15
# Nintcrit 4.5
# miu 0.04
# Nintmax 5.5
# Nintmin 0.48
# Ks 14.0
# Vmax 60.0
# Z 0.178
# KI 35.0
# K0 0.5
# Ka 0.05
# Topt 18.0
# Tmin 5.0
# Tmax 35.0
# n 5.0
# losses20 0.0016
# teta 1.047
# Sopt 25.0
# Smin 3.0
# Smax 48.0
# Shigh 30.0
# Slow 12.0
# KN 1.1
# dNextoutdt 0.014
# dNextindt 0.0
# dmoutdt 0.0
# Next00  4032.0
# dilution 0.0
#    Sample  Exp  Sleeve  Week Stage           Timei           Timeh  \
# 0     0.0    1       0   0.0     i  2019,3,12,13,0  2019,3,12,13,0
# 1     0.7    1       0   0.0     f  2019,3,12,13,0  2019,3,12,13,0
# 2     1.0    1       1   1.0     i  2019,3,19,13,0  2019,3,19,13,0
# 3     2.0    1       2   1.0     i  2019,3,19,13,0  2019,3,19,13,0
# 4     3.0    1       3   1.0     i  2019,3,19,13,0  2019,3,19,13,0
#
#              Time     DW   mmi  ...  Weighing  Trimming  Frequency  Amplitude  \
# 0  2019,3,12,13,0  0.750   NaN  ...       NaN       NaN        NaN        NaN
# 1  2019,3,19,13,0  0.753  50.0  ...       NaN       NaN        NaN        NaN
# 2  2019,3,19,13,0  0.144   NaN  ...       NaN       NaN        1.0     1000.0
# 3  2019,3,19,13,0  0.153   NaN  ...       NaN       NaN        1.0     1000.0
# 4  2019,3,19,13,0  0.159   NaN  ...       NaN       NaN        1.0     1000.0
#
#    Duration    Flux  Sporulated  Comment  Day  Comment2
# 0       NaN     NaN          No      NaN  NaN       NaN
# 1       NaN     NaN          No      NaN  NaN       NaN
# 2     168.0  1000.0          No      NaN  NaN       NaN
# 3     168.0  1000.0          No      NaN  NaN       NaN
# 4     168.0  1000.0          No      NaN  NaN       NaN
#
# [5 rows x 36 columns]

# %%
# b. process data (indoor measurements)

    # 1. Convert Time into hours
T = []
for i in df2['Sample'][:]:
    T1 = df2['Timei'][df2['Sample'].values.tolist().index(i)]
    T2 = df2['Time'][df2['Sample'].values.tolist().index(i)]
    T.append(Time_to_Hours(T1,T2))
df2['T'] = T

    # 2. Make a temp DF (df2_temp) by filtering the original df - remove 'wierd' results (i.e sporulation) 

df2_Reduced = df2[(df2.Treatment != 'Acclimation') & (df2.Week <= 3) & (df2.Stage != 'i') & (df2.Sporulated == 'No')]
df2_Reduced
# Out:
#      Sample  Exp  Sleeve  Week Stage            Timei            Timeh  \
# 11      1.7    1       1   1.0     f   2019,3,19,13,0   2019,3,19,13,0
# 12      2.7    1       2   1.0     f   2019,3,19,13,0   2019,3,19,13,0
# 13      3.7    1       3   1.0     f   2019,3,19,13,0   2019,3,19,13,0
# 14      4.7    1       4   1.0     f   2019,3,19,13,0   2019,3,19,13,0
# 15      5.7    1       5   1.0     f   2019,3,19,13,0   2019,3,19,13,0
# ..      ...  ...     ...   ...   ...              ...              ...
# 467   144.7    5       4   3.0     f  2019,11,28,12,0  2019,12,12,12,0
# 468   145.7    5       5   3.0     f  2019,11,28,12,0  2019,12,12,12,0
# 469   146.7    5       6   3.0     f  2019,11,28,12,0  2019,12,12,12,0
# 470   147.7    5       7   3.0     f  2019,11,28,12,0  2019,12,12,12,0
# 471   148.7    5       8   3.0     f  2019,11,28,12,0  2019,12,12,12,0
#
#                Time     DW  mmi  ...  Trimming  Frequency  Amplitude  \
# 11   2019,3,26,10,0  0.408  4.8  ...       0.0        1.0     1000.0
# 12   2019,3,26,10,0  0.426  5.1  ...       0.0        1.0     1000.0
# 13   2019,3,26,10,0  0.330  5.3  ...       0.0        1.0     1000.0
# 14   2019,3,26,10,0  0.267  5.2  ...       0.0        1.0     2000.0
# 15   2019,3,26,10,0  0.267  4.8  ...       0.0        1.0     2000.0
# ..              ...    ...  ...  ...       ...        ...        ...
# 467  2019,12,19,9,0  0.426  5.0  ...       0.0        2.0      500.0
# 468  2019,12,19,9,0  0.321  5.0  ...       0.0        3.0      500.0
# 469  2019,12,19,9,0  0.297  5.0  ...       0.0        3.0      500.0
# 470  2019,12,19,9,0  0.357  5.0  ...       0.0        5.0      200.0
# 471  2019,12,19,9,0  0.336  5.0  ...       0.0        5.0      200.0
#
#      Duration    Flux  Sporulated  Comment  Day  Comment2    T
# 11      168.0  1000.0          No      NaN  NaN       NaN  165
# 12      168.0  1000.0          No      NaN  NaN       NaN  165
# 13      168.0  1000.0          No      NaN  NaN       NaN  165
# 14        4.0  2000.0          No      NaN  NaN       NaN  165
# 15        4.0  2000.0          No      NaN  NaN       NaN  165
# ..        ...     ...         ...      ...  ...       ...  ...
# 467     168.0  1000.0          No      NaN  NaN       NaN  501
# 468     168.0  1500.0          No      NaN  NaN       NaN  501
# 469     168.0  1500.0          No      NaN  NaN       NaN  501
# 470     168.0  1000.0          No      NaN  NaN       NaN  501
# 471     168.0  1000.0          No      NaN  NaN       NaN  501
#
# [235 rows x 37 columns]

# %%
# 4. Calculate model results for:
#   a. Indoor system
    # I. Produce an array ("m/Nint/Next_mod_all") of all model results (hours 1-504) for each treatment

# %%
df2_Reduced
# Out:
#      Sample  Exp  Sleeve  Week Stage            Timei            Timeh  \
# 11      1.7    1       1   1.0     f   2019,3,19,13,0   2019,3,19,13,0
# 12      2.7    1       2   1.0     f   2019,3,19,13,0   2019,3,19,13,0
# 13      3.7    1       3   1.0     f   2019,3,19,13,0   2019,3,19,13,0
# 14      4.7    1       4   1.0     f   2019,3,19,13,0   2019,3,19,13,0
# 15      5.7    1       5   1.0     f   2019,3,19,13,0   2019,3,19,13,0
# ..      ...  ...     ...   ...   ...              ...              ...
# 467   144.7    5       4   3.0     f  2019,11,28,12,0  2019,12,12,12,0
# 468   145.7    5       5   3.0     f  2019,11,28,12,0  2019,12,12,12,0
# 469   146.7    5       6   3.0     f  2019,11,28,12,0  2019,12,12,12,0
# 470   147.7    5       7   3.0     f  2019,11,28,12,0  2019,12,12,12,0
# 471   148.7    5       8   3.0     f  2019,11,28,12,0  2019,12,12,12,0
#
#                Time     DW  mmi  ...  Trimming  Frequency  Amplitude  \
# 11   2019,3,26,10,0  0.408  4.8  ...       0.0        1.0     1000.0
# 12   2019,3,26,10,0  0.426  5.1  ...       0.0        1.0     1000.0
# 13   2019,3,26,10,0  0.330  5.3  ...       0.0        1.0     1000.0
# 14   2019,3,26,10,0  0.267  5.2  ...       0.0        1.0     2000.0
# 15   2019,3,26,10,0  0.267  4.8  ...       0.0        1.0     2000.0
# ..              ...    ...  ...  ...       ...        ...        ...
# 467  2019,12,19,9,0  0.426  5.0  ...       0.0        2.0      500.0
# 468  2019,12,19,9,0  0.321  5.0  ...       0.0        3.0      500.0
# 469  2019,12,19,9,0  0.297  5.0  ...       0.0        3.0      500.0
# 470  2019,12,19,9,0  0.357  5.0  ...       0.0        5.0      200.0
# 471  2019,12,19,9,0  0.336  5.0  ...       0.0        5.0      200.0
#
#      Duration    Flux  Sporulated  Comment  Day  Comment2    T
# 11      168.0  1000.0          No      NaN  NaN       NaN  165
# 12      168.0  1000.0          No      NaN  NaN       NaN  165
# 13      168.0  1000.0          No      NaN  NaN       NaN  165
# 14        4.0  2000.0          No      NaN  NaN       NaN  165
# 15        4.0  2000.0          No      NaN  NaN       NaN  165
# ..        ...     ...         ...      ...  ...       ...  ...
# 467     168.0  1000.0          No      NaN  NaN       NaN  501
# 468     168.0  1500.0          No      NaN  NaN       NaN  501
# 469     168.0  1500.0          No      NaN  NaN       NaN  501
# 470     168.0  1000.0          No      NaN  NaN       NaN  501
# 471     168.0  1000.0          No      NaN  NaN       NaN  501
#
# [235 rows x 37 columns]

# %%
df2_Reduced[(df2_Reduced['T'] > 504)]
# Out:
#      Sample  Exp  Sleeve  Week Stage           Timei            Timeh  \
# 342   111.7    4       1   3.0     f  2019,10,3,11,0  2019,10,17,10,0
# 343   112.7    4       2   3.0     f  2019,10,3,11,0  2019,10,17,10,0
# 344   113.7    4       3   3.0     f  2019,10,3,11,0  2019,10,17,10,0
# 366   114.7    4       4   3.0     f  2019,10,3,11,0  2019,10,17,10,0
# 367   115.7    4       5   3.0     f  2019,10,3,11,0  2019,10,17,10,0
# 368   116.7    4       6   3.0     f  2019,10,3,11,0  2019,10,17,10,0
# 369   117.7    4       7   3.0     f  2019,10,3,11,0  2019,10,17,10,0
# 370   118.7    4       8   3.0     f  2019,10,3,11,0  2019,10,17,10,0
# 416   119.7    4       9   3.0     f  2019,10,3,11,0  2019,10,17,10,0
#
#                 Time     DW  mmi  ...  Trimming  Frequency  Amplitude  \
# 342  2019,10,24,12,0  0.447  5.0  ...       2.0        1.0     1000.0
# 343  2019,10,24,12,0  0.504  5.0  ...       2.0        1.0     1000.0
# 344  2019,10,24,12,0  0.546  5.0  ...       0.0        1.0     1000.0
# 366  2019,10,24,12,0  0.390  5.0  ...       2.0        2.0      500.0
# 367  2019,10,24,12,0  0.447  5.0  ...       2.0        2.0      500.0
# 368  2019,10,24,12,0  0.423  5.0  ...       0.0        2.0      500.0
# 369  2019,10,24,12,0  0.414  5.0  ...       2.0        3.0      500.0
# 370  2019,10,24,12,0  0.411  5.0  ...       2.0        3.0      500.0
# 416  2019,10,24,12,0  0.441  5.0  ...       0.0        3.0      500.0
#
#      Duration    Flux  Sporulated      Comment  Day  Comment2    T
# 342     168.0  1000.0          No  Time effect  NaN       NaN  505
# 343     168.0  1000.0          No  Time effect  NaN       NaN  505
# 344     168.0  1000.0          No  Time effect  NaN       NaN  505
# 366     168.0  1000.0          No          NaN  NaN       NaN  505
# 367     168.0  1000.0          No          NaN  NaN       NaN  505
# 368     168.0  1000.0          No          NaN  NaN       NaN  505
# 369     168.0  1500.0          No          NaN  NaN       NaN  505
# 370     168.0  1500.0          No          NaN  NaN       NaN  505
# 416     168.0  1500.0          No          NaN  NaN       NaN  505
#
# [9 rows x 37 columns]

# %% [raw]
# miu = 0.045
# losses20 = 0.004
# Nintmax = 4.635
# Nintcrit = 2.409
# dNextoutdt = 0.199
# Ks = 13.1
# Vmax = 185.84
# KI = 18.4
# K0 = 0.49
# Ka = 0.17
# Smin = 0.1
# Sopt = 29.0
# Smax = 46.4
# Topt = 20.3
# Tmax = 31.4

# %%
# model simulations and measured data for the different treatments - fix problem with time (x axis) in 1000/1/168

TModAll = [] # Each sub-array has the time steps of a specific treatment (periods)
mExpAllTimes,NintExpAllTimes,NextExpAllTimes = [],[],[]
mModAll,NintModAll,NextModAll = [],[],[]

Treatments = ['1000/1/168','500/2/168','500/3/168','2000/1/168','200/5/168']

Temp = 22
#I0 = 80
S = 39 # fix salinity function and S=40

for i in Treatments:
    print('\nTreatment: ' + str(i))
    df2Temp = df2_Reduced[(df2_Reduced.Treatment == i)]
    mTemp = df2Temp[(np.isnan(df2Temp.DW) != True)]['DW']
    mTimeTemp = df2Temp[(np.isnan(df2Temp.DW) != True)]['T']
    NintTemp = df2Temp[(np.isnan(df2Temp.N) != True)]['N']
    NintTimeTemp = df2Temp[(np.isnan(df2Temp.N) != True)]['T']
    NextTemp = df2Temp[(np.isnan(df2Temp.NH4) != True)]['NH4']
    NextTimeTemp = df2Temp[(np.isnan(df2Temp.NH4) != True)]['T']
    mTemp = df2Temp[(~np.isnan(df2Temp.DW))]['DW']
    mTimeTemp = df2Temp[(~np.isnan(df2Temp.DW))]['T']
    NintTemp = df2Temp[(~np.isnan(df2Temp.N))]['N']
    NintTimeTemp = df2Temp[(~np.isnan(df2Temp.N))]['T']
    NextTemp = df2Temp[(~np.isnan(df2Temp.NH4))]['NH4']
    NextTimeTemp = df2Temp[(~np.isnan(df2Temp.NH4))]['T']
    print('Number of samples:\nm: ' + str(len(mTimeTemp)) + ' Nint: ' + str(len(NintTimeTemp)) + ' Next: ' + str(len(NextTimeTemp)))
    
    Tr = []
    Tr = i.split('/')
    Tr = [float(i) for i in Tr]
    Amplitude = Tr[0]
    Period = float(7/Tr[1]) # Period is in hours
    print(Period)
    Duration = Tr[2]/24
    
    NEXT, NINT, M, TT = [],[],[],[]

    n_days = Duration*3
    count_periods = 0
    
    #T1 = '2019,02,14,17,0'
    #T2 = df3Temp['Timei']
    #T2 = T2.tolist()[0]
    #t0 = Time_to_Hours(T1,T2)
    
    # hour = 0 is 1pm (Meiron)
    # in the indoor settings we have to solve for shorter periods, 
    # at the beginning of the Treatment we reset Nint, Next, m
    # at the beginning of each Period we set Next to the last Amplitude, 
    # m0 to the end of previous solution of ode()
    # 
    
    # Let's prepare the IO(t) function that will be supplied to odeint 
    # instead of a scalar. 
    
    all_treatment_hours = np.arange(0,n_days*24,dtype=np.int)
    
    # 8pm on the first day is zero crossing of this one 8pm - 10m = 7 hours
    offtimes = all_treatment_hours[np.mod(all_treatment_hours - 7,24) == 0]
    offtimes = np.r_[offtimes,all_treatment_hours[-1]+1] # last hour would be whatever
    
    # 6am on the next day is zero crossing of this one, 6am - 8pm is 10 hours
    ontimes = all_treatment_hours[np.mod(all_treatment_hours - 7 + 10,24) == 0]
    # and the iniital hour as we always start at 1pm, during ontime
    ontimes = np.r_[np.int(0),ontimes]
    
    # prepare the duty cycle
    I0set = np.zeros_like(all_treatment_hours)
    for s,e in zip(ontimes,offtimes):
        I0set[s:e] = 80
        
    # if you want to replace it by a "constant" I0 then replace the lines above with
    # the following line and then it will also give you a constant solution you had before
    
    # I0set = np.ones_like(all_treatment_hours)*80

    
    
    I0 = interpolate.interp1d(all_treatment_hours, I0set, bounds_error=False, fill_value="extrapolate")
    
    
    
 
    for hour in np.arange(0,n_days*24,round(Period*24,0)):
        print(hour)
        if hour == 0:
            print('Starting point')
            Nint_0 = Nint0
            m_0 = m0
            Next_0 = Amplitude
        
        if hour > 0 and np.mod(hour,round(Period*24,0)) == 0:
            count_periods = count_periods + 1
            
            if count_periods == Tr[1]:
                print('Duration')
                # reset everything, except Nint
                Nint_0 = NINT[-1][-1]
                Next_0 = Amplitude
                m_0 = m0
                count_periods = 0
            else:
                # period passed, not Duration
                # add amplitude, keep going 
                print('Period')
                Next_0 = NEXT[-1][-1] + Amplitude
                Nint_0 = NINT[-1][-1]
                m_0 = M[-1][-1]
   
                
        # Here we want to send odeint the times of the light sub-period or 
        # darkness sub-period

        x0 = [Next_0,Nint_0,m_0]
        # t = np.linspace(hour,hour+Period*24) # every time we solve ODE for 24 hours * Period
        t = np.arange(hour, hour+Period*24) # can also ask for report on round hours

        x = odeint(controlled_N_new,x0,t,args=(Nintmax,Nintmin,Vmax,Ks,dNextoutdt,dNextindt,miu,dmoutdt,Nintcrit,S,Z,KI,K0,Ka,
                                               Topt,Tmin,Tmax,losses20,teta,Sopt,Smin,Smax,n,umol_to_percent_DW,Temp,I0),printmessg=0,hmax=.1)

        NEXT.append(x[: , 0])
        NINT.append(x[: , 1])
        M.append(x[: , 2])
        TT.append(t)
        
        t_model = np.hstack(TT)
        Next_model = np.hstack(NEXT)
        Nint_model = np.hstack(NINT)
        m_model = np.hstack(M)
    
    TModAll.append(TT)
    mExpAllTimes.append(mTimeTemp)
    NintExpAllTimes.append(NintTimeTemp)
    NextExpAllTimes.append(NextTimeTemp)
    
    mModAll.append(m_model)
    NintModAll.append(Nint_model)
    NextModAll.append(Next_model)

    plot_result(t_model,Next_model,Nint_model,m_model,Nint=NintTemp,tNint=NintTimeTemp,m=mTemp,tm=mTimeTemp,Next=NextTemp,tNext=NextTimeTemp)
# Out:
# Treatment: 1000/1/168
# Number of samples:
# m: 50 Nint: 42 Next: 39
# 7.0
# 0.0
# Starting point
# 168.0
# Duration
# 336.0
# Duration
#
# Treatment: 500/2/168
# Number of samples:
# m: 86 Nint: 54 Next: 115
# 3.5
# 0.0
# Starting point
# 84.0
# Period
# 168.0
# Duration
# 252.0
# Period
# 336.0
# Duration
# 420.0
# Period
#
# Treatment: 500/3/168
# Number of samples:
# m: 24 Nint: 18 Next: 22
# 2.3333333333333335
# 0.0
# Starting point
# 56.0
# Period
# 112.0
# Period
# 168.0
# Duration
# 224.0
# Period
# 280.0
# Period
# 336.0
# Duration
# 392.0
# Period
# 448.0
# Period
#
# Treatment: 2000/1/168
# Number of samples:
# m: 9 Nint: 9 Next: 9
# 7.0
# 0.0
# Starting point
# 168.0
# Duration
# 336.0
# Duration
#
# Treatment: 200/5/168
# Number of samples:
# m: 5 Nint: 5 Next: 3
# 1.4
# 0.0
# Starting point
# 34.0
# Period
# 68.0
# Period
# 102.0
# Period
# 136.0
# Period
# 170.0
# Duration
# 204.0
# Period
# 238.0
# Period
# 272.0
# Period
# 306.0
# Period
# 340.0
# Duration
# 374.0
# Period
# 408.0
# Period
# 442.0
# Period
# 476.0
# Period

# %%
# This cell adjusts measurment time to model durations - so that maximum biomass measurements are compared to maximum biomass
# predictions and not to the initial stocking density (m0)

TModTemp = []
TModAllOrg = []
mModReducedAll, NintModReducedAll, NextModReducedAll = [],[],[]
for i in range(len(TModAll)): # loops over 5 treatments
    print(i)
    for j in range(len(TModAll[i])): # Loops over periods in each treatment
        Ttemp = TModAll[i][j]
        for k in Ttemp: #The model ends at 504 hours, but some measurement reach also 50 hours. This sets a 504 hour limit
            if k > 504:
                k = 504
            TModTemp.append(k)
    TModAllOrg.append(TModTemp)
    TModTemp = []

for i in range(len(TModAll)):
    gm = interpolate.interp1d(TModAllOrg[i], mModAll[i],kind = 'linear')
    mModReduced = []
    for j in mExpAllTimes[i]:
        #print(mExpAllTimes[i])
        if j >= 168 and j < 180:
            j = 167.9
        elif j >= 336 and j < 345:
            j = 335.9
        elif j > 504:
            j = 504
        #print(j)
        mModReduced.append(gm(j-1))
    
    mModReducedAll.append(mModReduced)
    gNint = interpolate.interp1d(TModAllOrg[i], NintModAll[i],kind = 'linear')
    NintModReduced = []
    for j in NintExpAllTimes[i]:
        if j >= 168 and j < 180:
            j = 167.9
        if j >= 336 and j < 345:
            j = 335.9
        if j > 504:
            j = 504
        NintModReduced.append(gNint(j-1))
    NintModReducedAll.append(NintModReduced)
    gNext = interpolate.interp1d(TModAllOrg[i], NextModAll[i],kind = 'linear')    
    NextModReduced = []
    for j in NextExpAllTimes[i]:
        if j >= 168 and j < 180:
            j = 167.9
        if j >= 336 and j < 345:
            j = 335.9
        if j > 504:
            j = 504
        NextModReduced.append(gNext(j-1))
    NextModReducedAll.append(NextModReduced)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
mSRE_All,NintSRE_All,NextSRE_All = [],[],[]
for i in range(len(Treatments)):
    mSRE,NintSRE,NextSRE = [],[],[]
    
    df2m = df2_Reduced[(np.isnan(df2_Reduced.DW) != True)&(df2_Reduced.Treatment == Treatments[i])]
    print('Treatment: ' + str(Treatments[i]) + '\n\nm\n')
    print('Number of samples: ' + str(len(df2m.Sample)) + '\n')
    k = 0
    for j in df2m.Sample:
        mexp = df2m.DW
        mmod = mModReducedAll[i]
        mSRE.append(((mexp.iloc[k]-mmod[k])/mmod[k])**2)
        print('Sample #' + str(math.floor(float(j))))
        print('Measured biomass: ' + str(round(mexp.iloc[k],3)))
        print('Modeled biomass: ' + str(round(float(mmod[k]),3)) + '\n')
        k = k + 1
    RMSREm = round((np.mean(mSRE))**0.5,3)
    mSRE_All.append(mSRE)
    print('The RMSRE of m in treamtment ' + str(Treatments[i]) + ' is: ' + str(RMSREm) + '\n')
    print('end of treatment ' + str(Treatments[i]) + '\n')
    
    df2Nint = df2_Reduced[(np.isnan(df2_Reduced.N) != True)][(df2_Reduced.Treatment == Treatments[i])]
    print('\nNint\n')
    print('Number of samples: ' + str(len(df2Nint.Sample)) + '\n')
    k = 0
    for j in df2Nint.Sample:
        Nintexp = df2Nint.N
        Nintmod = NintModReducedAll[i]
        NintSRE.append(((Nintexp.iloc[k]-Nintmod[k])/Nintmod[k])**2)
        print('Sample #' + str(math.floor(float(j))))
        print('Measured Nint: ' + str(round(float(Nintexp.iloc[k]),3)))     
        print('Modeled Nint: ' + str(round(float(Nintmod[k]),3)) + '\n')        
        k = k + 1
    RMSRENint = round((np.mean(NintSRE))**0.5,3)
    NintSRE_All.append(NintSRE)
    print('\nThe RMSRE of Nint in treamtment ' + str(Treatments[i]) + ' is: ' + str(RMSRENint) + '\n')
    
    df2Next = df2_Reduced[(np.isnan(df2_Reduced.NH4) != True)&(df2_Reduced.Treatment == Treatments[i])]
    print('\nNext\n')
    print('Number of samples: ' + str(len(df2Next.Sample)) + '\n')
    k = 0
    for j in df2Next.Sample:
        Nextexp = df2Next.NH4
        if Nextexp.iloc[k] < 0:
            Nextexp.iloc[k] = 0
        Nextmod = NextModReducedAll[i]
        NextSRE.append(((Nextexp.iloc[k]-Nextmod[k])/Nextmod[k])**2)
        print('Sample #' + str(math.floor(float(j))))
        print('Measured Next: ' + str(round(float(Nextexp.iloc[k]),3)))     
        print('Modeled Next: ' + str(round(float(Nextmod[k]),3)) + '\n')        
        k = k + 1
    RMSRENext = round((np.mean(NextSRE))**0.5,3)
    NextSRE_All.append(NextSRE)
    print('\nThe RMSRE of Next in treamtment ' + str(Treatments[i]) + ' is: ' + str(RMSRENext) + '\n')
print('End of treatment ' + str(Treatments[i]) + '\n')
# Out:
# Treatment: 1000/1/168
#
# m
#
# Number of samples: 50
#
# Sample #1
# Measured biomass: 0.408
# Modeled biomass: 0.437
#
# Sample #2
# Measured biomass: 0.426
# Modeled biomass: 0.437
#
# Sample #3
# Measured biomass: 0.33
# Modeled biomass: 0.437
#
# Sample #11
# Measured biomass: 0.294
# Modeled biomass: 0.445
#
# Sample #12
# Measured biomass: 0.213
# Modeled biomass: 0.445
#
# Sample #13
# Measured biomass: 0.228
# Modeled biomass: 0.445
#
# Sample #21
# Measured biomass: 0.267
# Modeled biomass: 0.445
#
# Sample #22
# Measured biomass: 0.174
# Modeled biomass: 0.445
#
# Sample #23
# Measured biomass: 0.228
# Modeled biomass: 0.445
#
# Sample #31
# Measured biomass: 0.423
# Modeled biomass: 0.44
#
# Sample #32
# Measured biomass: 0.387
# Modeled biomass: 0.44
#
# Sample #33
# Measured biomass: 0.456
# Modeled biomass: 0.44
#
# Sample #41
# Measured biomass: 0.231
# Modeled biomass: 0.44
#
# Sample #42
# Measured biomass: 0.228
# Modeled biomass: 0.44
#
# Sample #51
# Measured biomass: 0.27
# Modeled biomass: 0.437
#
# Sample #52
# Measured biomass: 0.231
# Modeled biomass: 0.437
#
# Sample #53
# Measured biomass: 0.195
# Modeled biomass: 0.437
#
# Sample #91
# Measured biomass: 0.201
# Modeled biomass: 0.248
#
# Sample #91
# Measured biomass: 0.261
# Modeled biomass: 0.349
#
# Sample #92
# Measured biomass: 0.225
# Modeled biomass: 0.248
#
# Sample #92
# Measured biomass: 0.276
# Modeled biomass: 0.349
#
# Sample #93
# Measured biomass: 0.195
# Modeled biomass: 0.248
#
# Sample #93
# Measured biomass: 0.204
# Modeled biomass: 0.349
#
# Sample #91
# Measured biomass: 0.336
# Modeled biomass: 0.45
#
# Sample #92
# Measured biomass: 0.348
# Modeled biomass: 0.45
#
# Sample #93
# Measured biomass: 0.234
# Modeled biomass: 0.45
#
# Sample #101
# Measured biomass: 0.246
# Modeled biomass: 0.241
#
# Sample #101
# Measured biomass: 0.327
# Modeled biomass: 0.344
#
# Sample #102
# Measured biomass: 0.3
# Modeled biomass: 0.241
#
# Sample #102
# Measured biomass: 0.42
# Modeled biomass: 0.344
#
# Sample #103
# Measured biomass: 0.273
# Modeled biomass: 0.241
#
# Sample #103
# Measured biomass: 0.378
# Modeled biomass: 0.344
#
# Sample #101
# Measured biomass: 0.423
# Modeled biomass: 0.445
#
# Sample #102
# Measured biomass: 0.474
# Modeled biomass: 0.445
#
# Sample #103
# Measured biomass: 0.441
# Modeled biomass: 0.445
#
# Sample #111
# Measured biomass: 0.288
# Modeled biomass: 0.248
#
# Sample #111
# Measured biomass: 0.357
# Modeled biomass: 0.331
#
# Sample #112
# Measured biomass: 0.309
# Modeled biomass: 0.248
#
# Sample #112
# Measured biomass: 0.423
# Modeled biomass: 0.331
#
# Sample #113
# Measured biomass: 0.312
# Modeled biomass: 0.248
#
# Sample #113
# Measured biomass: 0.432
# Modeled biomass: 0.331
#
# Sample #111
# Measured biomass: 0.447
# Modeled biomass: 0.451
#
# Sample #112
# Measured biomass: 0.504
# Modeled biomass: 0.451
#
# Sample #113
# Measured biomass: 0.546
# Modeled biomass: 0.451
#
# Sample #121
# Measured biomass: 0.408
# Modeled biomass: 0.45
#
# Sample #122
# Measured biomass: 0.36
# Modeled biomass: 0.45
#
# Sample #131
# Measured biomass: 0.453
# Modeled biomass: 0.45
#
# Sample #132
# Measured biomass: 0.429
# Modeled biomass: 0.45
#
# Sample #141
# Measured biomass: 0.288
# Modeled biomass: 0.437
#
# Sample #142
# Measured biomass: 0.297
# Modeled biomass: 0.437
#
# The RMSRE of m in treamtment 1000/1/168 is: 0.287
#
# end of treatment 1000/1/168
#
#
# Nint
#
# Number of samples: 42
#
# Sample #1
# Measured Nint: 2.071
# Modeled Nint: 2.086
#
# Sample #2
# Measured Nint: 2.014
# Modeled Nint: 2.086
#
# Sample #3
# Measured Nint: 2.179
# Modeled Nint: 2.086
#
# Sample #11
# Measured Nint: 2.609
# Modeled Nint: 2.069
#
# Sample #12
# Measured Nint: 2.98
# Modeled Nint: 2.069
#
# Sample #13
# Measured Nint: 2.865
# Modeled Nint: 2.069
#
# Sample #21
# Measured Nint: 3.105
# Modeled Nint: 2.075
#
# Sample #22
# Measured Nint: 3.726
# Modeled Nint: 2.075
#
# Sample #23
# Measured Nint: 3.402
# Modeled Nint: 2.075
#
# Sample #31
# Measured Nint: 1.761
# Modeled Nint: 2.068
#
# Sample #32
# Measured Nint: 1.727
# Modeled Nint: 2.068
#
# Sample #33
# Measured Nint: 1.628
# Modeled Nint: 2.068
#
# Sample #41
# Measured Nint: 2.875
# Modeled Nint: 2.099
#
# Sample #42
# Measured Nint: 3.131
# Modeled Nint: 2.099
#
# Sample #51
# Measured Nint: 3.227
# Modeled Nint: 2.123
#
# Sample #52
# Measured Nint: 3.043
# Modeled Nint: 2.123
#
# Sample #53
# Measured Nint: 3.462
# Modeled Nint: 2.123
#
# Sample #91
# Measured Nint: 3.883
# Modeled Nint: 3.428
#
# Sample #91
# Measured Nint: 2.897
# Modeled Nint: 2.696
#
# Sample #92
# Measured Nint: 2.21
# Modeled Nint: 3.428
#
# Sample #92
# Measured Nint: 3.022
# Modeled Nint: 2.696
#
# Sample #91
# Measured Nint: 2.197
# Modeled Nint: 2.013
#
# Sample #92
# Measured Nint: 2.837
# Modeled Nint: 2.013
#
# Sample #93
# Measured Nint: 2.414
# Modeled Nint: 2.013
#
# Sample #101
# Measured Nint: 3.848
# Modeled Nint: 3.503
#
# Sample #101
# Measured Nint: 2.678
# Modeled Nint: 2.781
#
# Sample #102
# Measured Nint: 3.131
# Modeled Nint: 3.503
#
# Sample #102
# Measured Nint: 1.97
# Modeled Nint: 2.781
#
# Sample #101
# Measured Nint: 2.218
# Modeled Nint: 2.069
#
# Sample #102
# Measured Nint: 2.732
# Modeled Nint: 2.069
#
# Sample #103
# Measured Nint: 2.18
# Modeled Nint: 2.069
#
# Sample #111
# Measured Nint: 2.359
# Modeled Nint: 2.909
#
# Sample #112
# Measured Nint: 1.923
# Modeled Nint: 3.466
#
# Sample #111
# Measured Nint: 2.136
# Modeled Nint: 2.046
#
# Sample #112
# Measured Nint: 3.957
# Modeled Nint: 2.046
#
# Sample #113
# Measured Nint: 2.035
# Modeled Nint: 2.046
#
# Sample #121
# Measured Nint: 1.237
# Modeled Nint: 2.013
#
# Sample #122
# Measured Nint: 1.983
# Modeled Nint: 2.013
#
# Sample #131
# Measured Nint: 1.459
# Modeled Nint: 2.043
#
# Sample #132
# Measured Nint: 1.835
# Modeled Nint: 2.043
#
# Sample #141
# Measured Nint: 2.083
# Modeled Nint: 2.123
#
# Sample #142
# Measured Nint: 2.164
# Modeled Nint: 2.123
#
#
# The RMSRE of Nint in treamtment 1000/1/168 is: 0.344
#
#
# Next
#
# Number of samples: 39
#
# Sample #31
# Measured Next: 18.105
# Modeled Next: -0.0
#
# Sample #32
# Measured Next: 56.574
# Modeled Next: -0.0
#
# Sample #33
# Measured Next: 28.356
# Modeled Next: -0.0
#
# Sample #42
# Measured Next: 0.0
# Modeled Next: 117.347
#
# Sample #41
# Measured Next: 22.818
# Modeled Next: -0.0
#
# Sample #42
# Measured Next: 34.594
# Modeled Next: -0.0
#
# Sample #51
# Measured Next: 0.0
# Modeled Next: 125.409
#
# Sample #52
# Measured Next: 42.773
# Modeled Next: 125.409
#
# Sample #53
# Measured Next: 103.888
# Modeled Next: 125.409
#
# Sample #91
# Measured Next: 182.469
# Modeled Next: 104.272
#
# Sample #91
# Measured Next: 21.994
# Modeled Next: 0.0
#
# Sample #92
# Measured Next: 221.068
# Modeled Next: 104.272
#
# Sample #92
# Measured Next: 13.294
# Modeled Next: 0.0
#
# Sample #93
# Measured Next: 450.425
# Modeled Next: 104.272
#
# Sample #93
# Measured Next: 4.284
# Modeled Next: 0.0
#
# Sample #91
# Measured Next: 0.636
# Modeled Next: -0.0
#
# Sample #92
# Measured Next: 6.218
# Modeled Next: -0.0
#
# Sample #93
# Measured Next: 6.139
# Modeled Next: -0.0
#
# Sample #101
# Measured Next: 257.35
# Modeled Next: 124.219
#
# Sample #101
# Measured Next: 59.343
# Modeled Next: 0.0
#
# Sample #102
# Measured Next: 201.633
# Modeled Next: 124.219
#
# Sample #102
# Measured Next: 191.0
# Modeled Next: 0.0
#
# Sample #103
# Measured Next: 132.98
# Modeled Next: 124.219
#
# Sample #103
# Measured Next: 15.127
# Modeled Next: 0.0
#
# Sample #101
# Measured Next: 4.73
# Modeled Next: -0.0
#
# Sample #102
# Measured Next: 5.545
# Modeled Next: -0.0
#
# Sample #103
# Measured Next: 0.627
# Modeled Next: -0.0
#
# Sample #111
# Measured Next: 358.6
# Modeled Next: 111.637
#
# Sample #111
# Measured Next: 79.968
# Modeled Next: 0.0
#
# Sample #112
# Measured Next: 117.795
# Modeled Next: 0.0
#
# Sample #113
# Measured Next: 227.71
# Modeled Next: 111.637
#
# Sample #113
# Measured Next: 10.544
# Modeled Next: 0.0
#
# Sample #111
# Measured Next: 30.883
# Modeled Next: -0.0
#
# Sample #112
# Measured Next: 1.818
# Modeled Next: -0.0
#
# Sample #113
# Measured Next: 12.382
# Modeled Next: -0.0
#
# Sample #121
# Measured Next: 0.0
# Modeled Next: -0.0
#
# Sample #122
# Measured Next: 2.108
# Modeled Next: -0.0
#
# Sample #131
# Measured Next: 0.0
# Modeled Next: -0.0
#
# Sample #132
# Measured Next: 0.0
# Modeled Next: -0.0
#
#
# The RMSRE of Next in treamtment 1000/1/168 is: 1.1778301687695858e+23
#
# Treatment: 500/2/168
#
# m
#
# Number of samples: 86
#
# Sample #37
# Measured biomass: 0.405
# Modeled biomass: 0.44
#
# Sample #38
# Measured biomass: 0.444
# Modeled biomass: 0.44
#
# Sample #39
# Measured biomass: 0.492
# Modeled biomass: 0.44
#
# Sample #47
# Measured biomass: 0.249
# Modeled biomass: 0.44
#
# Sample #49
# Measured biomass: 0.324
# Modeled biomass: 0.44
#
# Sample #57
# Measured biomass: 0.288
# Modeled biomass: 0.437
#
# Sample #58
# Measured biomass: 0.27
# Modeled biomass: 0.437
#
# Sample #59
# Measured biomass: 0.243
# Modeled biomass: 0.437
#
# Sample #61
# Measured biomass: 0.165
# Modeled biomass: 0.181
#
# Sample #61
# Measured biomass: 0.18
# Modeled biomass: 0.203
#
# Sample #61
# Measured biomass: 0.225
# Modeled biomass: 0.241
#
# Sample #61
# Measured biomass: 0.36
# Modeled biomass: 0.382
#
# Sample #62
# Measured biomass: 0.204
# Modeled biomass: 0.203
#
# Sample #62
# Measured biomass: 0.375
# Modeled biomass: 0.382
#
# Sample #63
# Measured biomass: 0.252
# Modeled biomass: 0.241
#
# Sample #64
# Measured biomass: 0.33
# Modeled biomass: 0.382
#
# Sample #61
# Measured biomass: 0.381
# Modeled biomass: 0.45
#
# Sample #62
# Measured biomass: 0.393
# Modeled biomass: 0.45
#
# Sample #63
# Measured biomass: 0.342
# Modeled biomass: 0.45
#
# Sample #64
# Measured biomass: 0.414
# Modeled biomass: 0.45
#
# Sample #65
# Measured biomass: 0.327
# Modeled biomass: 0.45
#
# Sample #66
# Measured biomass: 0.402
# Modeled biomass: 0.45
#
# Sample #67
# Measured biomass: 0.402
# Modeled biomass: 0.45
#
# Sample #68
# Measured biomass: 0.477
# Modeled biomass: 0.45
#
# Sample #69
# Measured biomass: 0.306
# Modeled biomass: 0.45
#
# Sample #71
# Measured biomass: 0.159
# Modeled biomass: 0.181
#
# Sample #71
# Measured biomass: 0.177
# Modeled biomass: 0.203
#
# Sample #71
# Measured biomass: 0.24
# Modeled biomass: 0.248
#
# Sample #71
# Measured biomass: 0.345
# Modeled biomass: 0.401
#
# Sample #72
# Measured biomass: 0.195
# Modeled biomass: 0.203
#
# Sample #72
# Measured biomass: 0.336
# Modeled biomass: 0.401
#
# Sample #73
# Measured biomass: 0.276
# Modeled biomass: 0.248
#
# Sample #74
# Measured biomass: 0.258
# Modeled biomass: 0.248
#
# Sample #75
# Measured biomass: 0.18
# Modeled biomass: 0.181
#
# Sample #75
# Measured biomass: 0.198
# Modeled biomass: 0.203
#
# Sample #75
# Measured biomass: 0.261
# Modeled biomass: 0.248
#
# Sample #75
# Measured biomass: 0.318
# Modeled biomass: 0.401
#
# Sample #76
# Measured biomass: 0.27
# Modeled biomass: 0.248
#
# Sample #71
# Measured biomass: 0.357
# Modeled biomass: 0.45
#
# Sample #72
# Measured biomass: 0.342
# Modeled biomass: 0.45
#
# Sample #73
# Measured biomass: 0.354
# Modeled biomass: 0.45
#
# Sample #74
# Measured biomass: 0.345
# Modeled biomass: 0.45
#
# Sample #75
# Measured biomass: 0.321
# Modeled biomass: 0.45
#
# Sample #76
# Measured biomass: 0.444
# Modeled biomass: 0.45
#
# Sample #77
# Measured biomass: 0.687
# Modeled biomass: 0.45
#
# Sample #78
# Measured biomass: 0.66
# Modeled biomass: 0.45
#
# Sample #79
# Measured biomass: 0.45
# Modeled biomass: 0.45
#
# Sample #81
# Measured biomass: 0.177
# Modeled biomass: 0.178
#
# Sample #81
# Measured biomass: 0.207
# Modeled biomass: 0.212
#
# Sample #81
# Measured biomass: 0.27
# Modeled biomass: 0.241
#
# Sample #81
# Measured biomass: 0.369
# Modeled biomass: 0.382
#
# Sample #83
# Measured biomass: 0.219
# Modeled biomass: 0.241
#
# Sample #84
# Measured biomass: 0.198
# Modeled biomass: 0.212
#
# Sample #85
# Measured biomass: 0.235
# Modeled biomass: 0.241
#
# Sample #81
# Measured biomass: 0.387
# Modeled biomass: 0.451
#
# Sample #83
# Measured biomass: 0.28
# Modeled biomass: 0.451
#
# Sample #84
# Measured biomass: 0.318
# Modeled biomass: 0.451
#
# Sample #85
# Measured biomass: 0.303
# Modeled biomass: 0.451
#
# Sample #86
# Measured biomass: 0.357
# Modeled biomass: 0.451
#
# Sample #87
# Measured biomass: 0.543
# Modeled biomass: 0.451
#
# Sample #88
# Measured biomass: 0.468
# Modeled biomass: 0.451
#
# Sample #89
# Measured biomass: 0.462
# Modeled biomass: 0.451
#
# Sample #104
# Measured biomass: 0.216
# Modeled biomass: 0.241
#
# Sample #104
# Measured biomass: 0.312
# Modeled biomass: 0.344
#
# Sample #105
# Measured biomass: 0.219
# Modeled biomass: 0.241
#
# Sample #105
# Measured biomass: 0.321
# Modeled biomass: 0.344
#
# Sample #106
# Measured biomass: 0.222
# Modeled biomass: 0.241
#
# Sample #106
# Measured biomass: 0.315
# Modeled biomass: 0.344
#
# Sample #104
# Measured biomass: 0.366
# Modeled biomass: 0.445
#
# Sample #105
# Measured biomass: 0.378
# Modeled biomass: 0.445
#
# Sample #106
# Measured biomass: 0.357
# Modeled biomass: 0.445
#
# Sample #114
# Measured biomass: 0.246
# Modeled biomass: 0.248
#
# Sample #114
# Measured biomass: 0.315
# Modeled biomass: 0.331
#
# Sample #115
# Measured biomass: 0.294
# Modeled biomass: 0.248
#
# Sample #115
# Measured biomass: 0.384
# Modeled biomass: 0.331
#
# Sample #116
# Measured biomass: 0.255
# Modeled biomass: 0.248
#
# Sample #116
# Measured biomass: 0.348
# Modeled biomass: 0.331
#
# Sample #114
# Measured biomass: 0.39
# Modeled biomass: 0.451
#
# Sample #115
# Measured biomass: 0.447
# Modeled biomass: 0.451
#
# Sample #116
# Measured biomass: 0.423
# Modeled biomass: 0.451
#
# Sample #123
# Measured biomass: 0.288
# Modeled biomass: 0.45
#
# Sample #124
# Measured biomass: 0.228
# Modeled biomass: 0.45
#
# Sample #133
# Measured biomass: 0.438
# Modeled biomass: 0.45
#
# Sample #134
# Measured biomass: 0.396
# Modeled biomass: 0.45
#
# Sample #143
# Measured biomass: 0.324
# Modeled biomass: 0.437
#
# Sample #144
# Measured biomass: 0.426
# Modeled biomass: 0.437
#
# The RMSRE of m in treamtment 500/2/168 is: 0.192
#
# end of treatment 500/2/168
#
#
# Nint
#
# Number of samples: 54
#
# Sample #37
# Measured Nint: 1.947
# Modeled Nint: 2.635
#
# Sample #38
# Measured Nint: 1.765
# Modeled Nint: 2.635
#
# Sample #39
# Measured Nint: 1.519
# Modeled Nint: 2.635
#
# Sample #47
# Measured Nint: 2.744
# Modeled Nint: 2.784
#
# Sample #49
# Measured Nint: 2.407
# Modeled Nint: 2.784
#
# Sample #57
# Measured Nint: 2.843
# Modeled Nint: 2.838
#
# Sample #58
# Measured Nint: 3.003
# Modeled Nint: 2.838
#
# Sample #59
# Measured Nint: 3.112
# Modeled Nint: 2.838
#
# Sample #61
# Measured Nint: 3.0
# Modeled Nint: 2.647
#
# Sample #62
# Measured Nint: 2.934
# Modeled Nint: 3.096
#
# Sample #63
# Measured Nint: 2.132
# Modeled Nint: 2.967
#
# Sample #64
# Measured Nint: 2.407
# Modeled Nint: 3.095
#
# Sample #61
# Measured Nint: 2.128
# Modeled Nint: 2.564
#
# Sample #62
# Measured Nint: 2.05
# Modeled Nint: 2.564
#
# Sample #63
# Measured Nint: 2.199
# Modeled Nint: 2.564
#
# Sample #64
# Measured Nint: 2.266
# Modeled Nint: 2.564
#
# Sample #65
# Measured Nint: 2.421
# Modeled Nint: 2.564
#
# Sample #66
# Measured Nint: 2.251
# Modeled Nint: 2.564
#
# Sample #71
# Measured Nint: 2.6
# Modeled Nint: 3.096
#
# Sample #72
# Measured Nint: 2.508
# Modeled Nint: 3.333
#
# Sample #73
# Measured Nint: 2.965
# Modeled Nint: 3.205
#
# Sample #75
# Measured Nint: 3.327
# Modeled Nint: 3.042
#
# Sample #71
# Measured Nint: 2.393
# Modeled Nint: 2.709
#
# Sample #72
# Measured Nint: 2.256
# Modeled Nint: 2.709
#
# Sample #73
# Measured Nint: 2.757
# Modeled Nint: 2.709
#
# Sample #74
# Measured Nint: 2.572
# Modeled Nint: 2.709
#
# Sample #75
# Measured Nint: 2.947
# Modeled Nint: 2.709
#
# Sample #76
# Measured Nint: 2.031
# Modeled Nint: 2.709
#
# Sample #77
# Measured Nint: 1.838
# Modeled Nint: 2.709
#
# Sample #78
# Measured Nint: 2.023
# Modeled Nint: 2.709
#
# Sample #79
# Measured Nint: 3.241
# Modeled Nint: 2.709
#
# Sample #81
# Measured Nint: 2.225
# Modeled Nint: 3.363
#
# Sample #84
# Measured Nint: 2.415
# Modeled Nint: 3.369
#
# Sample #81
# Measured Nint: 2.963
# Modeled Nint: 2.734
#
# Sample #83
# Measured Nint: 2.879
# Modeled Nint: 2.734
#
# Sample #84
# Measured Nint: 2.456
# Modeled Nint: 2.734
#
# Sample #85
# Measured Nint: 2.755
# Modeled Nint: 2.734
#
# Sample #86
# Measured Nint: 2.237
# Modeled Nint: 2.734
#
# Sample #104
# Measured Nint: 2.794
# Modeled Nint: 3.299
#
# Sample #104
# Measured Nint: 2.889
# Modeled Nint: 3.394
#
# Sample #105
# Measured Nint: 2.532
# Modeled Nint: 3.299
#
# Sample #105
# Measured Nint: 2.348
# Modeled Nint: 3.394
#
# Sample #104
# Measured Nint: 2.639
# Modeled Nint: 2.744
#
# Sample #105
# Measured Nint: 2.366
# Modeled Nint: 2.744
#
# Sample #114
# Measured Nint: 2.096
# Modeled Nint: 3.479
#
# Sample #115
# Measured Nint: 2.6
# Modeled Nint: 3.269
#
# Sample #114
# Measured Nint: 2.544
# Modeled Nint: 2.734
#
# Sample #115
# Measured Nint: 3.065
# Modeled Nint: 2.734
#
# Sample #123
# Measured Nint: 2.208
# Modeled Nint: 2.564
#
# Sample #124
# Measured Nint: 2.547
# Modeled Nint: 2.564
#
# Sample #133
# Measured Nint: 2.371
# Modeled Nint: 2.709
#
# Sample #134
# Measured Nint: 3.317
# Modeled Nint: 2.709
#
# Sample #143
# Measured Nint: 2.665
# Modeled Nint: 2.838
#
# Sample #144
# Measured Nint: 2.036
# Modeled Nint: 2.838
#
#
# The RMSRE of Nint in treamtment 500/2/168 is: 0.189
#
#
# Next
#
# Number of samples: 115
#
# Sample #37
# Measured Next: 0.0
# Modeled Next: 0.022
#
# Sample #39
# Measured Next: 0.0
# Modeled Next: 0.022
#
# Sample #37
# Measured Next: 0.0
# Modeled Next: 0.0
#
# Sample #39
# Measured Next: 0.0
# Modeled Next: 0.0
#
# Sample #47
# Measured Next: 0.0
# Modeled Next: 0.443
#
# Sample #48
# Measured Next: 1.457
# Modeled Next: 0.443
#
# Sample #49
# Measured Next: 0.0
# Modeled Next: 0.443
#
# Sample #47
# Measured Next: 1.91
# Modeled Next: 0.0
#
# Sample #49
# Measured Next: 0.0
# Modeled Next: 0.0
#
# Sample #57
# Measured Next: 9.693
# Modeled Next: 1.192
#
# Sample #58
# Measured Next: 19.056
# Modeled Next: 1.192
#
# Sample #59
# Measured Next: 0.0
# Modeled Next: 1.192
#
# Sample #57
# Measured Next: 1.499
# Modeled Next: 0.0
#
# Sample #58
# Measured Next: 14.58
# Modeled Next: 0.0
#
# Sample #59
# Measured Next: 7.188
# Modeled Next: 0.0
#
# Sample #61
# Measured Next: 0.74
# Modeled Next: 0.037
#
# Sample #62
# Measured Next: 0.0
# Modeled Next: 0.037
#
# Sample #63
# Measured Next: 0.0
# Modeled Next: 0.037
#
# Sample #64
# Measured Next: 0.2
# Modeled Next: 0.037
#
# Sample #65
# Measured Next: 7.76
# Modeled Next: 0.037
#
# Sample #66
# Measured Next: 8.598
# Modeled Next: 0.037
#
# Sample #67
# Measured Next: 189.48
# Modeled Next: 277.598
#
# Sample #67
# Measured Next: 153.266
# Modeled Next: 249.991
#
# Sample #67
# Measured Next: 0.0
# Modeled Next: 79.996
#
# Sample #67
# Measured Next: 7.757
# Modeled Next: 0.063
#
# Sample #67
# Measured Next: 310.976
# Modeled Next: 0.001
#
# Sample #68
# Measured Next: 326.448
# Modeled Next: 277.598
#
# Sample #68
# Measured Next: 219.827
# Modeled Next: 249.991
#
# Sample #68
# Measured Next: 232.134
# Modeled Next: 79.996
#
# Sample #68
# Measured Next: 182.807
# Modeled Next: 0.063
#
# Sample #68
# Measured Next: 197.57
# Modeled Next: 0.001
#
# Sample #69
# Measured Next: 371.264
# Modeled Next: 277.598
#
# Sample #69
# Measured Next: 155.066
# Modeled Next: 249.991
#
# Sample #69
# Measured Next: 116.164
# Modeled Next: 79.996
#
# Sample #69
# Measured Next: 76.054
# Modeled Next: 0.063
#
# Sample #69
# Measured Next: 105.2
# Modeled Next: 0.001
#
# Sample #61
# Measured Next: 0.0
# Modeled Next: 0.0
#
# Sample #62
# Measured Next: 0.0
# Modeled Next: 0.0
#
# Sample #63
# Measured Next: 4.574
# Modeled Next: 0.0
#
# Sample #64
# Measured Next: 20.898
# Modeled Next: 0.0
#
# Sample #65
# Measured Next: 0.0
# Modeled Next: 0.0
#
# Sample #66
# Measured Next: 4.979
# Modeled Next: 0.0
#
# Sample #67
# Measured Next: 244.872
# Modeled Next: 0.0
#
# Sample #68
# Measured Next: 131.622
# Modeled Next: 0.0
#
# Sample #69
# Measured Next: 108.424
# Modeled Next: 0.0
#
# Sample #71
# Measured Next: 8.622
# Modeled Next: 0.275
#
# Sample #72
# Measured Next: 5.162
# Modeled Next: 0.166
#
# Sample #73
# Measured Next: 14.37
# Modeled Next: 0.275
#
# Sample #74
# Measured Next: 265.085
# Modeled Next: 269.006
#
# Sample #74
# Measured Next: 32.796
# Modeled Next: 111.359
#
# Sample #74
# Measured Next: 0.0
# Modeled Next: 0.275
#
# Sample #74
# Measured Next: 0.0
# Modeled Next: 0.0
#
# Sample #74
# Measured Next: 0.0
# Modeled Next: 0.0
#
# Sample #75
# Measured Next: 0.0
# Modeled Next: 251.896
#
# Sample #75
# Measured Next: 113.269
# Modeled Next: 111.359
#
# Sample #75
# Measured Next: 13.245
# Modeled Next: 0.275
#
# Sample #75
# Measured Next: 22.016
# Modeled Next: 0.0
#
# Sample #75
# Measured Next: 21.784
# Modeled Next: 0.0
#
# Sample #76
# Measured Next: 178.738
# Modeled Next: 251.896
#
# Sample #76
# Measured Next: 47.537
# Modeled Next: 111.359
#
# Sample #76
# Measured Next: 1.741
# Modeled Next: 0.275
#
# Sample #77
# Measured Next: 48.038
# Modeled Next: 0.275
#
# Sample #78
# Measured Next: 0.0
# Modeled Next: 0.275
#
# Sample #79
# Measured Next: 1.234
# Modeled Next: 0.275
#
# Sample #71
# Measured Next: 0.0
# Modeled Next: 0.0
#
# Sample #72
# Measured Next: 3.905
# Modeled Next: 0.0
#
# Sample #73
# Measured Next: 27.649
# Modeled Next: 0.0
#
# Sample #74
# Measured Next: 299.14
# Modeled Next: 0.0
#
# Sample #75
# Measured Next: 9.111
# Modeled Next: 0.0
#
# Sample #76
# Measured Next: 0.0
# Modeled Next: 0.0
#
# Sample #77
# Measured Next: 0.0
# Modeled Next: 0.0
#
# Sample #78
# Measured Next: 0.0
# Modeled Next: 0.0
#
# Sample #79
# Measured Next: 0.0
# Modeled Next: 0.0
#
# Sample #81
# Measured Next: 45.105
# Modeled Next: 264.454
#
# Sample #81
# Measured Next: 0.0
# Modeled Next: 86.999
#
# Sample #81
# Measured Next: 390.14
# Modeled Next: 1.192
#
# Sample #81
# Measured Next: 0.0
# Modeled Next: 0.005
#
# Sample #82
# Measured Next: 99.205
# Modeled Next: 264.454
#
# Sample #83
# Measured Next: 73.663
# Modeled Next: 264.454
#
# Sample #83
# Measured Next: 85.626
# Modeled Next: 86.999
#
# Sample #83
# Measured Next: 352.898
# Modeled Next: 1.192
#
# Sample #83
# Measured Next: 0.0
# Modeled Next: 0.005
#
# Sample #84
# Measured Next: 0.0
# Modeled Next: 86.999
#
# Sample #84
# Measured Next: 330.027
# Modeled Next: 1.192
#
# Sample #84
# Measured Next: 8.905
# Modeled Next: 0.005
#
# Sample #81
# Measured Next: 14.728
# Modeled Next: 0.0
#
# Sample #83
# Measured Next: 2.321
# Modeled Next: 0.0
#
# Sample #84
# Measured Next: 9.643
# Modeled Next: 0.0
#
# Sample #85
# Measured Next: 30.181
# Modeled Next: 0.0
#
# Sample #86
# Measured Next: 8.084
# Modeled Next: 0.0
#
# Sample #87
# Measured Next: 0.0
# Modeled Next: 0.0
# Sample #88
# Measured Next: 0.0
# Modeled Next: 0.0
#
# Sample #89
# Measured Next: 0.0
# Modeled Next: 0.0
#
# Sample #104
# Measured Next: 49.986
# Modeled Next: 0.698
#
# Sample #104
# Measured Next: 184.794
# Modeled Next: 76.894
#
# Sample #105
# Measured Next: 5.294
# Modeled Next: 0.698
#
# Sample #105
# Measured Next: 160.715
# Modeled Next: 76.894
#
# Sample #106
# Measured Next: 8.727
# Modeled Next: 0.698
#
# Sample #106
# Measured Next: 137.516
# Modeled Next: 76.894
#
# Sample #104
# Measured Next: 6.806
# Modeled Next: 0.0
#
# Sample #105
# Measured Next: 7.608
# Modeled Next: 0.0
#
# Sample #106
# Measured Next: 0.512
# Modeled Next: 0.0
#
# Sample #114
# Measured Next: 9.537
# Modeled Next: 0.491
#
# Sample #114
# Measured Next: 0.0
# Modeled Next: 105.576
#
# Sample #115
# Measured Next: 2.89
# Modeled Next: 0.491
#
# Sample #115
# Measured Next: 132.902
# Modeled Next: 105.576
#
# Sample #116
# Measured Next: 130.843
# Modeled Next: 0.491
#
# Sample #116
# Measured Next: 0.801
# Modeled Next: 105.576
#
# Sample #114
# Measured Next: 4.461
# Modeled Next: 0.0
#
# Sample #115
# Measured Next: 3.85
# Modeled Next: 0.0
#
# Sample #116
# Measured Next: 6.151
# Modeled Next: 0.0
#
# Sample #123
# Measured Next: 0.0
# Modeled Next: 0.0
#
# Sample #124
# Measured Next: 0.0
# Modeled Next: 0.0
#
# Sample #133
# Measured Next: 7.631
# Modeled Next: 0.0
#
# Sample #134
# Measured Next: 1.534
# Modeled Next: 0.0
#
#
# The RMSRE of Next in treamtment 500/2/168 is: 4.243692554273216e+16
#
# Treatment: 500/3/168
#
# m
#
# Number of samples: 24
#
# Sample #107
# Measured biomass: 0.24
# Modeled biomass: 0.241
#
# Sample #107
# Measured biomass: 0.345
# Modeled biomass: 0.344
#
# Sample #108
# Measured biomass: 0.216
# Modeled biomass: 0.241
#
# Sample #108
# Measured biomass: 0.348
# Modeled biomass: 0.344
#
# Sample #109
# Measured biomass: 0.24
# Modeled biomass: 0.241
#
# Sample #109
# Measured biomass: 0.366
# Modeled biomass: 0.344
#
# Sample #107
# Measured biomass: 0.411
# Modeled biomass: 0.445
#
# Sample #108
# Measured biomass: 0.378
# Modeled biomass: 0.445
#
# Sample #109
# Measured biomass: 0.45
# Modeled biomass: 0.445
#
# Sample #117
# Measured biomass: 0.291
# Modeled biomass: 0.248
#
# Sample #117
# Measured biomass: 0.345
# Modeled biomass: 0.331
#
# Sample #118
# Measured biomass: 0.276
# Modeled biomass: 0.248
#
# Sample #118
# Measured biomass: 0.339
# Modeled biomass: 0.331
#
# Sample #119
# Measured biomass: 0.291
# Modeled biomass: 0.248
#
# Sample #119
# Measured biomass: 0.384
# Modeled biomass: 0.331
#
# Sample #117
# Measured biomass: 0.414
# Modeled biomass: 0.451
#
# Sample #118
# Measured biomass: 0.411
# Modeled biomass: 0.451
#
# Sample #119
# Measured biomass: 0.441
# Modeled biomass: 0.451
#
# Sample #125
# Measured biomass: 0.282
# Modeled biomass: 0.45
#
# Sample #126
# Measured biomass: 0.312
# Modeled biomass: 0.45
#
# Sample #135
# Measured biomass: 0.477
# Modeled biomass: 0.45
#
# Sample #136
# Measured biomass: 0.375
# Modeled biomass: 0.45
#
# Sample #145
# Measured biomass: 0.321
# Modeled biomass: 0.437
#
# Sample #146
# Measured biomass: 0.297
# Modeled biomass: 0.437
#
# The RMSRE of m in treamtment 500/3/168 is: 0.158
#
# end of treatment 500/3/168
#
#
# Nint
#
# Number of samples: 18
#
# Sample #107
# Measured Nint: 3.388
# Modeled Nint: 3.756
#
# Sample #107
# Measured Nint: 2.863
# Modeled Nint: 3.742
#
# Sample #108
# Measured Nint: 4.016
# Modeled Nint: 3.756
#
# Sample #108
# Measured Nint: 3.164
# Modeled Nint: 3.742
#
# Sample #107
# Measured Nint: 3.496
# Modeled Nint: 3.784
#
# Sample #108
# Measured Nint: 1.919
# Modeled Nint: 3.784
#
# Sample #109
# Measured Nint: 3.159
# Modeled Nint: 3.784
#
# Sample #117
# Measured Nint: 3.164
# Modeled Nint: 3.84
#
# Sample #118
# Measured Nint: 3.964
# Modeled Nint: 3.746
#
# Sample #118
# Measured Nint: 3.905
# Modeled Nint: 3.84
#
# Sample #118
# Measured Nint: 3.783
# Modeled Nint: 3.753
#
# Sample #119
# Measured Nint: 3.34
# Modeled Nint: 3.753
#
# Sample #125
# Measured Nint: 2.92
# Modeled Nint: 3.529
#
# Sample #126
# Measured Nint: 3.212
# Modeled Nint: 3.529
#
# Sample #135
# Measured Nint: 2.269
# Modeled Nint: 3.737
#
# Sample #136
# Measured Nint: 3.036
# Modeled Nint: 3.737
#
# Sample #145
# Measured Nint: 3.045
# Modeled Nint: 3.884
#
# Sample #146
# Measured Nint: 3.574
# Modeled Nint: 3.884
#
#
# The RMSRE of Nint in treamtment 500/3/168 is: 0.197
#
#
# Next
#
# Number of samples: 22
#
# Sample #107
# Measured Next: 30.296
# Modeled Next: 421.511
#
# Sample #107
# Measured Next: 70.221
# Modeled Next: 442.08
#
# Sample #108
# Measured Next: 4.428
# Modeled Next: 421.511
#
# Sample #108
# Measured Next: 133.714
# Modeled Next: 442.08
#
# Sample #109
# Measured Next: 9.218
# Modeled Next: 421.511
#
# Sample #109
# Measured Next: 226.212
# Modeled Next: 442.08
#
# Sample #107
# Measured Next: 179.653
# Modeled Next: 1.031
#
# Sample #108
# Measured Next: 244.267
# Modeled Next: 1.031
#
# Sample #109
# Measured Next: 75.224
# Modeled Next: 1.031
#
# Sample #117
# Measured Next: 18.911
# Modeled Next: 408.095
#
# Sample #117
# Measured Next: 29.642
# Modeled Next: 487.374
#
# Sample #118
# Measured Next: 21.413
# Modeled Next: 408.095
#
# Sample #118
# Measured Next: 3.058
# Modeled Next: 487.374
#
# Sample #119
# Measured Next: 0.0
# Modeled Next: 408.095
#
# Sample #119
# Measured Next: 165.092
# Modeled Next: 487.374
#
# Sample #117
# Measured Next: 11.708
# Modeled Next: 0.818
#
# Sample #118
# Measured Next: 8.868
# Modeled Next: 0.818
#
# Sample #119
# Measured Next: 13.232
# Modeled Next: 0.818
#
# Sample #125
# Measured Next: 18.459
# Modeled Next: 0.014
#
# Sample #126
# Measured Next: 90.379
# Modeled Next: 0.014
#
# Sample #135
# Measured Next: 0.0
# Modeled Next: 0.589
#
# Sample #136
# Measured Next: 0.0
# Modeled Next: 0.589
#
#
# The RMSRE of Next in treamtment 500/3/168 is: 1370.641
#
# Treatment: 2000/1/168
#
# m
#
# Number of samples: 9
#
# Sample #34
# Measured biomass: 0.369
# Modeled biomass: 0.44
#
# Sample #35
# Measured biomass: 0.438
# Modeled biomass: 0.44
#
# Sample #36
# Measured biomass: 0.351
# Modeled biomass: 0.44
#
# Sample #44
# Measured biomass: 0.219
# Modeled biomass: 0.44
#
# Sample #45
# Measured biomass: 0.258
# Modeled biomass: 0.44
#
# Sample #46
# Measured biomass: 0.222
# Modeled biomass: 0.44
#
# Sample #54
# Measured biomass: 0.204
# Modeled biomass: 0.437
#
# Sample #55
# Measured biomass: 0.168
# Modeled biomass: 0.437
#
# Sample #56
# Measured biomass: 0.129
# Modeled biomass: 0.437
#
# The RMSRE of m in treamtment 2000/1/168 is: 0.459
#
# end of treatment 2000/1/168
#
#
# Nint
#
# Number of samples: 9
#
# Sample #34
# Measured Nint: 3.174
# Modeled Nint: 2.804
#
# Sample #35
# Measured Nint: 2.743
# Modeled Nint: 2.804
#
# Sample #36
# Measured Nint: 3.273
# Modeled Nint: 2.804
#
# Sample #44
# Measured Nint: 3.768
# Modeled Nint: 2.928
#
# Sample #45
# Measured Nint: 4.235
# Modeled Nint: 2.928
#
# Sample #46
# Measured Nint: 3.917
# Modeled Nint: 2.928
#
# Sample #54
# Measured Nint: 3.849
# Modeled Nint: 2.971
#
# Sample #55
# Measured Nint: 4.194
# Modeled Nint: 2.971
#
# Sample #56
# Measured Nint: 4.203
# Modeled Nint: 2.971
#
#
# The RMSRE of Nint in treamtment 2000/1/168 is: 0.311
#
#
# Next
#
# Number of samples: 9
#
# Sample #34
# Measured Next: 14.568
# Modeled Next: 0.0
#
# Sample #35
# Measured Next: 98.751
# Modeled Next: 0.0
#
# Sample #36
# Measured Next: 27.739
# Modeled Next: 0.0
#
# Sample #43
# Measured Next: 84.008
# Modeled Next: 521.652
#
# Sample #44
# Measured Next: 417.874
# Modeled Next: 521.652
#
# Sample #45
# Measured Next: 287.854
# Modeled Next: 521.652
#
# Sample #54
# Measured Next: 397.748
# Modeled Next: 539.164
#
# Sample #55
# Measured Next: 979.517
# Modeled Next: 539.164
#
# Sample #56
# Measured Next: 666.435
# Modeled Next: 539.164
#
#
# The RMSRE of Next in treamtment 2000/1/168 is: 1.9445280178329956e+16
#
# Treatment: 200/5/168
#
# m
#
# Number of samples: 5
#
# Sample #137
# Measured biomass: 0.378
# Modeled biomass: 0.434
#
# Sample #138
# Measured biomass: 0.336
# Modeled biomass: 0.434
#
# Sample #139
# Measured biomass: 0.339
# Modeled biomass: 0.434
#
# Sample #147
# Measured biomass: 0.357
# Modeled biomass: 0.409
#
# Sample #148
# Measured biomass: 0.336
# Modeled biomass: 0.409
#
# The RMSRE of m in treamtment 200/5/168 is: 0.181
#
# end of treatment 200/5/168
#
#
# Nint
#
# Number of samples: 5
#
# Sample #137
# Measured Nint: 1.618
# Modeled Nint: 3.342
#
# Sample #138
# Measured Nint: 1.796
# Modeled Nint: 3.342
#
# Sample #139
# Measured Nint: 1.918
# Modeled Nint: 3.342
#
# Sample #147
# Measured Nint: 1.969
# Modeled Nint: 3.578
#
# Sample #148
# Measured Nint: 2.008
# Modeled Nint: 3.578
#
#
# The RMSRE of Nint in treamtment 200/5/168 is: 0.46
#
#
# Next
#
# Number of samples: 3
#
# Sample #137
# Measured Next: 138.333
# Modeled Next: 0.02
#
# Sample #138
# Measured Next: 0.0
# Modeled Next: 0.02
#
# Sample #139
# Measured Next: 0.0
# Modeled Next: 0.02
#
#
# The RMSRE of Next in treamtment 200/5/168 is: 3972.554
#
# End of treatment 200/5/168
# C:\Users\meiro\Anaconda3new\lib\site-packages\ipykernel_launcher.py:22: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\meiro\Anaconda3new\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\meiro\Anaconda3new\lib\site-packages\ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
mSRE_All,NintSRE_All,NextSRE_All = [],[],[]
for i in range(len(Treatments)):
    mSRE,NintSRE,NextSRE = [],[],[]
    
    df2m = df2_Reduced[(np.isnan(df2_Reduced.DW) != True)&(df2_Reduced.Treatment == Treatments[i])]
    print('Treatment: ' + str(Treatments[i]) + '\n\nm\n')
    print('Number of samples: ' + str(len(df2m.Sample)) + '\n')
    k = 0
    for j in df2m.Sample:
        mexp = df2m.DW
        mmod = mModReducedAll[i]
        mSRE.append(((mexp.iloc[k]-mmod[k])/mmod[k])**2)
        print('Sample #' + str(math.floor(float(j))))
        print('Measured biomass: ' + str(round(mexp.iloc[k],3)))
        print('Modeled biomass: ' + str(round(float(mmod[k]),3)) + '\n')
        k = k + 1
    RMSREm = round((np.mean(mSRE))**0.5,3)
    mSRE_All.append(mSRE)
    print('The RMSRE of m in treamtment ' + str(Treatments[i]) + ' is: ' + str(RMSREm) + '\n')
    print('end of treatment ' + str(Treatments[i]) + '\n')
    
    df2Nint = df2_Reduced[(np.isnan(df2_Reduced.N) != True)][(df2_Reduced.Treatment == Treatments[i])]
    print('\nNint\n')
    print('Number of samples: ' + str(len(df2Nint.Sample)) + '\n')
    k = 0
    for j in df2Nint.Sample:
        Nintexp = df2Nint.N
        Nintmod = NintModReducedAll[i]
        NintSRE.append(((Nintexp.iloc[k]-Nintmod[k])/Nintmod[k])**2)
        print('Sample #' + str(math.floor(float(j))))
        print('Measured Nint: ' + str(round(float(Nintexp.iloc[k]),3)))     
        print('Modeled Nint: ' + str(round(float(Nintmod[k]),3)) + '\n')        
        k = k + 1
    RMSRENint = round((np.mean(NintSRE))**0.5,3)
    NintSRE_All.append(NintSRE)
    print('\nThe RMSRE of Nint in treamtment ' + str(Treatments[i]) + ' is: ' + str(RMSRENint) + '\n')
    
    df2Next = df2_Reduced[(np.isnan(df2_Reduced.NH4) != True)&(df2_Reduced.Treatment == Treatments[i])]
    #print('\nNext\n')
    #print('Number of samples: ' + str(len(df2Next.Sample)) + '\n')
    k = 0
    for j in df2Next.Sample:
        Nextexp = df2Next.NH4
        if Nextexp.iloc[k] < 0:
            Nextexp.iloc[k] = 0
        Nextmod = NextModReducedAll[i]
        NextSRE.append(((Nextexp.iloc[k]-Nextmod[k])/Nextmod[k])**2)
        #print('Sample #' + str(math.floor(float(j))))
        #print('Measured Next: ' + str(round(float(Nextexp.iloc[k]),3)))     
        #print('Modeled Next: ' + str(round(float(Nextmod[k]),3)) + '\n')        
        k = k + 1
    RMSRENext = round((np.mean(NextSRE))**0.5,3)
    NextSRE_All.append(NextSRE)
    #print('\nThe RMSRE of Next in treamtment ' + str(Treatments[i]) + ' is: ' + str(RMSRENext) + '\n')
print('End of treatment ' + str(Treatments[i]) + '\n')
# Out:
# Treatment: 1000/1/168
#
# m
#
# Number of samples: 50
#
# Sample #1
# Measured biomass: 0.408
# Modeled biomass: 0.437
#
# Sample #2
# Measured biomass: 0.426
# Modeled biomass: 0.437
#
# Sample #3
# Measured biomass: 0.33
# Modeled biomass: 0.437
#
# Sample #11
# Measured biomass: 0.294
# Modeled biomass: 0.445
#
# Sample #12
# Measured biomass: 0.213
# Modeled biomass: 0.445
#
# Sample #13
# Measured biomass: 0.228
# Modeled biomass: 0.445
#
# Sample #21
# Measured biomass: 0.267
# Modeled biomass: 0.445
#
# Sample #22
# Measured biomass: 0.174
# Modeled biomass: 0.445
#
# Sample #23
# Measured biomass: 0.228
# Modeled biomass: 0.445
#
# Sample #31
# Measured biomass: 0.423
# Modeled biomass: 0.44
#
# Sample #32
# Measured biomass: 0.387
# Modeled biomass: 0.44
#
# Sample #33
# Measured biomass: 0.456
# Modeled biomass: 0.44
#
# Sample #41
# Measured biomass: 0.231
# Modeled biomass: 0.44
#
# Sample #42
# Measured biomass: 0.228
# Modeled biomass: 0.44
#
# Sample #51
# Measured biomass: 0.27
# Modeled biomass: 0.437
#
# Sample #52
# Measured biomass: 0.231
# Modeled biomass: 0.437
#
# Sample #53
# Measured biomass: 0.195
# Modeled biomass: 0.437
#
# Sample #91
# Measured biomass: 0.201
# Modeled biomass: 0.248
#
# Sample #91
# Measured biomass: 0.261
# Modeled biomass: 0.349
#
# Sample #92
# Measured biomass: 0.225
# Modeled biomass: 0.248
#
# Sample #92
# Measured biomass: 0.276
# Modeled biomass: 0.349
#
# Sample #93
# Measured biomass: 0.195
# Modeled biomass: 0.248
#
# Sample #93
# Measured biomass: 0.204
# Modeled biomass: 0.349
#
# Sample #91
# Measured biomass: 0.336
# Modeled biomass: 0.45
#
# Sample #92
# Measured biomass: 0.348
# Modeled biomass: 0.45
#
# Sample #93
# Measured biomass: 0.234
# Modeled biomass: 0.45
#
# Sample #101
# Measured biomass: 0.246
# Modeled biomass: 0.241
#
# Sample #101
# Measured biomass: 0.327
# Modeled biomass: 0.344
#
# Sample #102
# Measured biomass: 0.3
# Modeled biomass: 0.241
#
# Sample #102
# Measured biomass: 0.42
# Modeled biomass: 0.344
#
# Sample #103
# Measured biomass: 0.273
# Modeled biomass: 0.241
#
# Sample #103
# Measured biomass: 0.378
# Modeled biomass: 0.344
#
# Sample #101
# Measured biomass: 0.423
# Modeled biomass: 0.445
#
# Sample #102
# Measured biomass: 0.474
# Modeled biomass: 0.445
#
# Sample #103
# Measured biomass: 0.441
# Modeled biomass: 0.445
#
# Sample #111
# Measured biomass: 0.288
# Modeled biomass: 0.248
#
# Sample #111
# Measured biomass: 0.357
# Modeled biomass: 0.331
#
# Sample #112
# Measured biomass: 0.309
# Modeled biomass: 0.248
#
# Sample #112
# Measured biomass: 0.423
# Modeled biomass: 0.331
#
# Sample #113
# Measured biomass: 0.312
# Modeled biomass: 0.248
#
# Sample #113
# Measured biomass: 0.432
# Modeled biomass: 0.331
#
# Sample #111
# Measured biomass: 0.447
# Modeled biomass: 0.451
#
# Sample #112
# Measured biomass: 0.504
# Modeled biomass: 0.451
#
# Sample #113
# Measured biomass: 0.546
# Modeled biomass: 0.451
#
# Sample #121
# Measured biomass: 0.408
# Modeled biomass: 0.45
#
# Sample #122
# Measured biomass: 0.36
# Modeled biomass: 0.45
#
# Sample #131
# Measured biomass: 0.453
# Modeled biomass: 0.45
#
# Sample #132
# Measured biomass: 0.429
# Modeled biomass: 0.45
#
# Sample #141
# Measured biomass: 0.288
# Modeled biomass: 0.437
#
# Sample #142
# Measured biomass: 0.297
# Modeled biomass: 0.437
#
# The RMSRE of m in treamtment 1000/1/168 is: 0.287
#
# end of treatment 1000/1/168
#
#
# Nint
#
# Number of samples: 42
#
# Sample #1
# Measured Nint: 2.071
# Modeled Nint: 2.086
#
# Sample #2
# Measured Nint: 2.014
# Modeled Nint: 2.086
#
# Sample #3
# Measured Nint: 2.179
# Modeled Nint: 2.086
#
# Sample #11
# Measured Nint: 2.609
# Modeled Nint: 2.069
#
# Sample #12
# Measured Nint: 2.98
# Modeled Nint: 2.069
#
# Sample #13
# Measured Nint: 2.865
# Modeled Nint: 2.069
#
# Sample #21
# Measured Nint: 3.105
# Modeled Nint: 2.075
#
# Sample #22
# Measured Nint: 3.726
# Modeled Nint: 2.075
#
# Sample #23
# Measured Nint: 3.402
# Modeled Nint: 2.075
#
# Sample #31
# Measured Nint: 1.761
# Modeled Nint: 2.068
#
# Sample #32
# Measured Nint: 1.727
# Modeled Nint: 2.068
#
# Sample #33
# Measured Nint: 1.628
# Modeled Nint: 2.068
#
# Sample #41
# Measured Nint: 2.875
# Modeled Nint: 2.099
#
# Sample #42
# Measured Nint: 3.131
# Modeled Nint: 2.099
#
# Sample #51
# Measured Nint: 3.227
# Modeled Nint: 2.123
#
# Sample #52
# Measured Nint: 3.043
# Modeled Nint: 2.123
#
# Sample #53
# Measured Nint: 3.462
# Modeled Nint: 2.123
#
# Sample #91
# Measured Nint: 3.883
# Modeled Nint: 3.428
#
# Sample #91
# Measured Nint: 2.897
# Modeled Nint: 2.696
#
# Sample #92
# Measured Nint: 2.21
# Modeled Nint: 3.428
#
# Sample #92
# Measured Nint: 3.022
# Modeled Nint: 2.696
#
# Sample #91
# Measured Nint: 2.197
# Modeled Nint: 2.013
#
# Sample #92
# Measured Nint: 2.837
# Modeled Nint: 2.013
#
# Sample #93
# Measured Nint: 2.414
# Modeled Nint: 2.013
#
# Sample #101
# Measured Nint: 3.848
# Modeled Nint: 3.503
#
# Sample #101
# Measured Nint: 2.678
# Modeled Nint: 2.781
#
# Sample #102
# Measured Nint: 3.131
# Modeled Nint: 3.503
#
# Sample #102
# Measured Nint: 1.97
# Modeled Nint: 2.781
#
# Sample #101
# Measured Nint: 2.218
# Modeled Nint: 2.069
#
# Sample #102
# Measured Nint: 2.732
# Modeled Nint: 2.069
#
# Sample #103
# Measured Nint: 2.18
# Modeled Nint: 2.069
#
# Sample #111
# Measured Nint: 2.359
# Modeled Nint: 2.909
#
# Sample #112
# Measured Nint: 1.923
# Modeled Nint: 3.466
#
# Sample #111
# Measured Nint: 2.136
# Modeled Nint: 2.046
#
# Sample #112
# Measured Nint: 3.957
# Modeled Nint: 2.046
#
# Sample #113
# Measured Nint: 2.035
# Modeled Nint: 2.046
#
# Sample #121
# Measured Nint: 1.237
# Modeled Nint: 2.013
#
# Sample #122
# Measured Nint: 1.983
# Modeled Nint: 2.013
#
# Sample #131
# Measured Nint: 1.459
# Modeled Nint: 2.043
#
# Sample #132
# Measured Nint: 1.835
# Modeled Nint: 2.043
#
# Sample #141
# Measured Nint: 2.083
# Modeled Nint: 2.123
#
# Sample #142
# Measured Nint: 2.164
# Modeled Nint: 2.123
#
#
# The RMSRE of Nint in treamtment 1000/1/168 is: 0.344
#
# Treatment: 500/2/168
#
# m
#
# Number of samples: 86
#
# Sample #37
# Measured biomass: 0.405
# Modeled biomass: 0.44
#
# Sample #38
# Measured biomass: 0.444
# Modeled biomass: 0.44
#
# Sample #39
# Measured biomass: 0.492
# Modeled biomass: 0.44
#
# Sample #47
# Measured biomass: 0.249
# Modeled biomass: 0.44
#
# Sample #49
# Measured biomass: 0.324
# Modeled biomass: 0.44
#
# Sample #57
# Measured biomass: 0.288
# Modeled biomass: 0.437
#
# Sample #58
# Measured biomass: 0.27
# Modeled biomass: 0.437
#
# Sample #59
# Measured biomass: 0.243
# Modeled biomass: 0.437
#
# Sample #61
# Measured biomass: 0.165
# Modeled biomass: 0.181
#
# Sample #61
# Measured biomass: 0.18
# Modeled biomass: 0.203
#
# Sample #61
# Measured biomass: 0.225
# Modeled biomass: 0.241
#
# Sample #61
# Measured biomass: 0.36
# Modeled biomass: 0.382
#
# Sample #62
# Measured biomass: 0.204
# Modeled biomass: 0.203
#
# Sample #62
# Measured biomass: 0.375
# Modeled biomass: 0.382
#
# Sample #63
# Measured biomass: 0.252
# Modeled biomass: 0.241
#
# Sample #64
# Measured biomass: 0.33
# Modeled biomass: 0.382
#
# Sample #61
# Measured biomass: 0.381
# Modeled biomass: 0.45
#
# Sample #62
# Measured biomass: 0.393
# Modeled biomass: 0.45
#
# Sample #63
# Measured biomass: 0.342
# Modeled biomass: 0.45
#
# Sample #64
# Measured biomass: 0.414
# Modeled biomass: 0.45
#
# Sample #65
# Measured biomass: 0.327
# Modeled biomass: 0.45
#
# Sample #66
# Measured biomass: 0.402
# Modeled biomass: 0.45
#
# Sample #67
# Measured biomass: 0.402
# Modeled biomass: 0.45
#
# Sample #68
# Measured biomass: 0.477
# Modeled biomass: 0.45
#
# Sample #69
# Measured biomass: 0.306
# Modeled biomass: 0.45
#
# Sample #71
# Measured biomass: 0.159
# Modeled biomass: 0.181
#
# Sample #71
# Measured biomass: 0.177
# Modeled biomass: 0.203
#
# Sample #71
# Measured biomass: 0.24
# Modeled biomass: 0.248
#
# Sample #71
# Measured biomass: 0.345
# Modeled biomass: 0.401
#
# Sample #72
# Measured biomass: 0.195
# Modeled biomass: 0.203
#
# Sample #72
# Measured biomass: 0.336
# Modeled biomass: 0.401
#
# Sample #73
# Measured biomass: 0.276
# Modeled biomass: 0.248
#
# Sample #74
# Measured biomass: 0.258
# Modeled biomass: 0.248
#
# Sample #75
# Measured biomass: 0.18
# Modeled biomass: 0.181
#
# Sample #75
# Measured biomass: 0.198
# Modeled biomass: 0.203
#
# Sample #75
# Measured biomass: 0.261
# Modeled biomass: 0.248
#
# Sample #75
# Measured biomass: 0.318
# Modeled biomass: 0.401
#
# Sample #76
# Measured biomass: 0.27
# Modeled biomass: 0.248
#
# Sample #71
# Measured biomass: 0.357
# Modeled biomass: 0.45
#
# Sample #72
# Measured biomass: 0.342
# Modeled biomass: 0.45
#
# Sample #73
# Measured biomass: 0.354
# Modeled biomass: 0.45
#
# Sample #74
# Measured biomass: 0.345
# Modeled biomass: 0.45
#
# Sample #75
# Measured biomass: 0.321
# Modeled biomass: 0.45
#
# Sample #76
# Measured biomass: 0.444
# Modeled biomass: 0.45
#
# Sample #77
# Measured biomass: 0.687
# Modeled biomass: 0.45
#
# Sample #78
# Measured biomass: 0.66
# Modeled biomass: 0.45
#
# Sample #79
# Measured biomass: 0.45
# Modeled biomass: 0.45
#
# Sample #81
# Measured biomass: 0.177
# Modeled biomass: 0.178
#
# Sample #81
# Measured biomass: 0.207
# Modeled biomass: 0.212
#
# Sample #81
# Measured biomass: 0.27
# Modeled biomass: 0.241
#
# Sample #81
# Measured biomass: 0.369
# Modeled biomass: 0.382
#
# Sample #83
# Measured biomass: 0.219
# Modeled biomass: 0.241
#
# Sample #84
# Measured biomass: 0.198
# Modeled biomass: 0.212
#
# Sample #85
# Measured biomass: 0.235
# Modeled biomass: 0.241
#
# Sample #81
# Measured biomass: 0.387
# Modeled biomass: 0.451
#
# Sample #83
# Measured biomass: 0.28
# Modeled biomass: 0.451
#
# Sample #84
# Measured biomass: 0.318
# Modeled biomass: 0.451
#
# Sample #85
# Measured biomass: 0.303
# Modeled biomass: 0.451
#
# Sample #86
# Measured biomass: 0.357
# Modeled biomass: 0.451
#
# Sample #87
# Measured biomass: 0.543
# Modeled biomass: 0.451
#
# Sample #88
# Measured biomass: 0.468
# Modeled biomass: 0.451
#
# Sample #89
# Measured biomass: 0.462
# Modeled biomass: 0.451
#
# Sample #104
# Measured biomass: 0.216
# Modeled biomass: 0.241
#
# Sample #104
# Measured biomass: 0.312
# Modeled biomass: 0.344
#
# Sample #105
# Measured biomass: 0.219
# Modeled biomass: 0.241
#
# Sample #105
# Measured biomass: 0.321
# Modeled biomass: 0.344
#
# Sample #106
# Measured biomass: 0.222
# Modeled biomass: 0.241
#
# Sample #106
# Measured biomass: 0.315
# Modeled biomass: 0.344
#
# Sample #104
# Measured biomass: 0.366
# Modeled biomass: 0.445
#
# Sample #105
# Measured biomass: 0.378
# Modeled biomass: 0.445
#
# Sample #106
# Measured biomass: 0.357
# Modeled biomass: 0.445
#
# Sample #114
# Measured biomass: 0.246
# Modeled biomass: 0.248
#
# Sample #114
# Measured biomass: 0.315
# Modeled biomass: 0.331
#
# Sample #115
# Measured biomass: 0.294
# Modeled biomass: 0.248
#
# Sample #115
# Measured biomass: 0.384
# Modeled biomass: 0.331
#
# Sample #116
# Measured biomass: 0.255
# Modeled biomass: 0.248
#
# Sample #116
# Measured biomass: 0.348
# Modeled biomass: 0.331
#
# Sample #114
# Measured biomass: 0.39
# Modeled biomass: 0.451
#
# Sample #115
# Measured biomass: 0.447
# Modeled biomass: 0.451
#
# Sample #116
# Measured biomass: 0.423
# Modeled biomass: 0.451
#
# Sample #123
# Measured biomass: 0.288
# Modeled biomass: 0.45
#
# Sample #124
# Measured biomass: 0.228
# Modeled biomass: 0.45
#
# Sample #133
# Measured biomass: 0.438
# Modeled biomass: 0.45
#
# Sample #134
# Measured biomass: 0.396
# Modeled biomass: 0.45
#
# Sample #143
# Measured biomass: 0.324
# Modeled biomass: 0.437
#
# Sample #144
# Measured biomass: 0.426
# Modeled biomass: 0.437
#
# The RMSRE of m in treamtment 500/2/168 is: 0.192
#
# end of treatment 500/2/168
#
#
# Nint
#
# Number of samples: 54
#
# Sample #37
# Measured Nint: 1.947
# Modeled Nint: 2.635
#
# Sample #38
# Measured Nint: 1.765
# Modeled Nint: 2.635
#
# Sample #39
# Measured Nint: 1.519
# Modeled Nint: 2.635
#
# Sample #47
# Measured Nint: 2.744
# Modeled Nint: 2.784
#
# Sample #49
# Measured Nint: 2.407
# Modeled Nint: 2.784
#
# Sample #57
# Measured Nint: 2.843
# Modeled Nint: 2.838
#
# Sample #58
# Measured Nint: 3.003
# Modeled Nint: 2.838
#
# Sample #59
# Measured Nint: 3.112
# Modeled Nint: 2.838
#
# Sample #61
# Measured Nint: 3.0
# Modeled Nint: 2.647
#
# Sample #62
# Measured Nint: 2.934
# Modeled Nint: 3.096
#
# Sample #63
# Measured Nint: 2.132
# Modeled Nint: 2.967
#
# Sample #64
# Measured Nint: 2.407
# Modeled Nint: 3.095
#
# Sample #61
# Measured Nint: 2.128
# Modeled Nint: 2.564
#
# Sample #62
# Measured Nint: 2.05
# Modeled Nint: 2.564
#
# Sample #63
# Measured Nint: 2.199
# Modeled Nint: 2.564
#
# Sample #64
# Measured Nint: 2.266
# Modeled Nint: 2.564
#
# Sample #65
# Measured Nint: 2.421
# Modeled Nint: 2.564
#
# Sample #66
# Measured Nint: 2.251
# Modeled Nint: 2.564
#
# Sample #71
# Measured Nint: 2.6
# Modeled Nint: 3.096
#
# Sample #72
# Measured Nint: 2.508
# Modeled Nint: 3.333
#
# Sample #73
# Measured Nint: 2.965
# Modeled Nint: 3.205
#
# Sample #75
# Measured Nint: 3.327
# Modeled Nint: 3.042
#
# Sample #71
# Measured Nint: 2.393
# Modeled Nint: 2.709
#
# Sample #72
# Measured Nint: 2.256
# Modeled Nint: 2.709
#
# Sample #73
# Measured Nint: 2.757
# Modeled Nint: 2.709
# Sample #74
# Measured Nint: 2.572
# Modeled Nint: 2.709
#
# Sample #75
# Measured Nint: 2.947
# Modeled Nint: 2.709
#
# Sample #76
# Measured Nint: 2.031
# Modeled Nint: 2.709
#
# Sample #77
# Measured Nint: 1.838
# Modeled Nint: 2.709
#
# Sample #78
# Measured Nint: 2.023
# Modeled Nint: 2.709
#
# Sample #79
# Measured Nint: 3.241
# Modeled Nint: 2.709
#
# Sample #81
# Measured Nint: 2.225
# Modeled Nint: 3.363
#
# Sample #84
# Measured Nint: 2.415
# Modeled Nint: 3.369
#
# Sample #81
# Measured Nint: 2.963
# Modeled Nint: 2.734
#
# Sample #83
# Measured Nint: 2.879
# Modeled Nint: 2.734
#
# Sample #84
# Measured Nint: 2.456
# Modeled Nint: 2.734
#
# Sample #85
# Measured Nint: 2.755
# Modeled Nint: 2.734
#
# Sample #86
# Measured Nint: 2.237
# Modeled Nint: 2.734
#
# Sample #104
# Measured Nint: 2.794
# Modeled Nint: 3.299
#
# Sample #104
# Measured Nint: 2.889
# Modeled Nint: 3.394
#
# Sample #105
# Measured Nint: 2.532
# Modeled Nint: 3.299
#
# Sample #105
# Measured Nint: 2.348
# Modeled Nint: 3.394
#
# Sample #104
# Measured Nint: 2.639
# Modeled Nint: 2.744
#
# Sample #105
# Measured Nint: 2.366
# Modeled Nint: 2.744
#
# Sample #114
# Measured Nint: 2.096
# Modeled Nint: 3.479
#
# Sample #115
# Measured Nint: 2.6
# Modeled Nint: 3.269
#
# Sample #114
# Measured Nint: 2.544
# Modeled Nint: 2.734
#
# Sample #115
# Measured Nint: 3.065
# Modeled Nint: 2.734
#
# Sample #123
# Measured Nint: 2.208
# Modeled Nint: 2.564
#
# Sample #124
# Measured Nint: 2.547
# Modeled Nint: 2.564
#
# Sample #133
# Measured Nint: 2.371
# Modeled Nint: 2.709
#
# Sample #134
# Measured Nint: 3.317
# Modeled Nint: 2.709
#
# Sample #143
# Measured Nint: 2.665
# Modeled Nint: 2.838
#
# Sample #144
# Measured Nint: 2.036
# Modeled Nint: 2.838
#
#
# The RMSRE of Nint in treamtment 500/2/168 is: 0.189
#
# Treatment: 500/3/168
#
# m
#
# Number of samples: 24
#
# Sample #107
# Measured biomass: 0.24
# Modeled biomass: 0.241
#
# Sample #107
# Measured biomass: 0.345
# Modeled biomass: 0.344
#
# Sample #108
# Measured biomass: 0.216
# Modeled biomass: 0.241
#
# Sample #108
# Measured biomass: 0.348
# Modeled biomass: 0.344
#
# Sample #109
# Measured biomass: 0.24
# Modeled biomass: 0.241
#
# Sample #109
# Measured biomass: 0.366
# Modeled biomass: 0.344
#
# Sample #107
# Measured biomass: 0.411
# Modeled biomass: 0.445
#
# Sample #108
# Measured biomass: 0.378
# Modeled biomass: 0.445
#
# Sample #109
# Measured biomass: 0.45
# Modeled biomass: 0.445
#
# Sample #117
# Measured biomass: 0.291
# Modeled biomass: 0.248
#
# Sample #117
# Measured biomass: 0.345
# Modeled biomass: 0.331
#
# Sample #118
# Measured biomass: 0.276
# Modeled biomass: 0.248
#
# Sample #118
# Measured biomass: 0.339
# Modeled biomass: 0.331
#
# Sample #119
# Measured biomass: 0.291
# Modeled biomass: 0.248
#
# Sample #119
# Measured biomass: 0.384
# Modeled biomass: 0.331
#
# Sample #117
# Measured biomass: 0.414
# Modeled biomass: 0.451
#
# Sample #118
# Measured biomass: 0.411
# Modeled biomass: 0.451
#
# Sample #119
# Measured biomass: 0.441
# Modeled biomass: 0.451
#
# Sample #125
# Measured biomass: 0.282
# Modeled biomass: 0.45
#
# Sample #126
# Measured biomass: 0.312
# Modeled biomass: 0.45
#
# Sample #135
# Measured biomass: 0.477
# Modeled biomass: 0.45
#
# Sample #136
# Measured biomass: 0.375
# Modeled biomass: 0.45
#
# Sample #145
# Measured biomass: 0.321
# Modeled biomass: 0.437
#
# Sample #146
# Measured biomass: 0.297
# Modeled biomass: 0.437
#
# The RMSRE of m in treamtment 500/3/168 is: 0.158
#
# end of treatment 500/3/168
#
#
# Nint
#
# Number of samples: 18
#
# Sample #107
# Measured Nint: 3.388
# Modeled Nint: 3.756
#
# Sample #107
# Measured Nint: 2.863
# Modeled Nint: 3.742
#
# Sample #108
# Measured Nint: 4.016
# Modeled Nint: 3.756
#
# Sample #108
# Measured Nint: 3.164
# Modeled Nint: 3.742
#
# Sample #107
# Measured Nint: 3.496
# Modeled Nint: 3.784
#
# Sample #108
# Measured Nint: 1.919
# Modeled Nint: 3.784
#
# Sample #109
# Measured Nint: 3.159
# Modeled Nint: 3.784
#
# Sample #117
# Measured Nint: 3.164
# Modeled Nint: 3.84
#
# Sample #118
# Measured Nint: 3.964
# Modeled Nint: 3.746
#
# Sample #118
# Measured Nint: 3.905
# Modeled Nint: 3.84
#
# Sample #118
# Measured Nint: 3.783
# Modeled Nint: 3.753
#
# Sample #119
# Measured Nint: 3.34
# Modeled Nint: 3.753
#
# Sample #125
# Measured Nint: 2.92
# Modeled Nint: 3.529
#
# Sample #126
# Measured Nint: 3.212
# Modeled Nint: 3.529
#
# Sample #135
# Measured Nint: 2.269
# Modeled Nint: 3.737
#
# Sample #136
# Measured Nint: 3.036
# Modeled Nint: 3.737
#
# Sample #145
# Measured Nint: 3.045
# Modeled Nint: 3.884
#
# Sample #146
# Measured Nint: 3.574
# Modeled Nint: 3.884
#
#
# The RMSRE of Nint in treamtment 500/3/168 is: 0.197
#
# Treatment: 2000/1/168
#
# m
#
# Number of samples: 9
#
# Sample #34
# Measured biomass: 0.369
# Modeled biomass: 0.44
#
# Sample #35
# Measured biomass: 0.438
# Modeled biomass: 0.44
#
# Sample #36
# Measured biomass: 0.351
# Modeled biomass: 0.44
#
# Sample #44
# Measured biomass: 0.219
# Modeled biomass: 0.44
#
# Sample #45
# Measured biomass: 0.258
# Modeled biomass: 0.44
#
# Sample #46
# Measured biomass: 0.222
# Modeled biomass: 0.44
#
# Sample #54
# Measured biomass: 0.204
# Modeled biomass: 0.437
#
# Sample #55
# Measured biomass: 0.168
# Modeled biomass: 0.437
#
# Sample #56
# Measured biomass: 0.129
# Modeled biomass: 0.437
#
# The RMSRE of m in treamtment 2000/1/168 is: 0.459
#
# end of treatment 2000/1/168
#
#
# Nint
#
# Number of samples: 9
#
# Sample #34
# Measured Nint: 3.174
# Modeled Nint: 2.804
#
# Sample #35
# Measured Nint: 2.743
# Modeled Nint: 2.804
#
# Sample #36
# Measured Nint: 3.273
# Modeled Nint: 2.804
#
# Sample #44
# Measured Nint: 3.768
# Modeled Nint: 2.928
#
# Sample #45
# Measured Nint: 4.235
# Modeled Nint: 2.928
#
# Sample #46
# Measured Nint: 3.917
# Modeled Nint: 2.928
#
# Sample #54
# Measured Nint: 3.849
# Modeled Nint: 2.971
#
# Sample #55
# Measured Nint: 4.194
# Modeled Nint: 2.971
#
# Sample #56
# Measured Nint: 4.203
# Modeled Nint: 2.971
#
#
# The RMSRE of Nint in treamtment 2000/1/168 is: 0.311
#
# Treatment: 200/5/168
#
# m
#
# Number of samples: 5
#
# Sample #137
# Measured biomass: 0.378
# Modeled biomass: 0.434
#
# Sample #138
# Measured biomass: 0.336
# Modeled biomass: 0.434
#
# Sample #139
# Measured biomass: 0.339
# Modeled biomass: 0.434
#
# Sample #147
# Measured biomass: 0.357
# Modeled biomass: 0.409
#
# Sample #148
# Measured biomass: 0.336
# Modeled biomass: 0.409
#
# The RMSRE of m in treamtment 200/5/168 is: 0.181
#
# end of treatment 200/5/168
#
#
# Nint
#
# Number of samples: 5
#
# Sample #137
# Measured Nint: 1.618
# Modeled Nint: 3.342
#
# Sample #138
# Measured Nint: 1.796
# Modeled Nint: 3.342
#
# Sample #139
# Measured Nint: 1.918
# Modeled Nint: 3.342
#
# Sample #147
# Measured Nint: 1.969
# Modeled Nint: 3.578
#
# Sample #148
# Measured Nint: 2.008
# Modeled Nint: 3.578
#
#
# The RMSRE of Nint in treamtment 200/5/168 is: 0.46
#
# End of treatment 200/5/168
# C:\Users\meiro\Anaconda3new\lib\site-packages\ipykernel_launcher.py:22: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\meiro\Anaconda3new\lib\site-packages\ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
mSRE_AllTemp = []
for i in range(len(mSRE_All)):
    for j in range(len(mSRE_All[i])):
        mSRE_AllTemp.append(mSRE_All[i][j])
RMSREm = round((np.mean(mSRE_AllTemp))**0.5,3)
print(RMSREm)
# Out:
# 0.239

# %%
NintSRE_AllTemp = []
for i in range(len(NintSRE_All)):
    for j in range(len(NintSRE_All[i])):
        NintSRE_AllTemp.append(NintSRE_All[i][j])
RMSRENint = round((np.mean(NintSRE_AllTemp))**0.5,3)
print(RMSRENint)
# Out:
# 0.273

# %%
NextSRE_AllTemp = []
for i in range(len(NextSRE_All)):
    for j in range(len(NextSRE_All[i])):
        NextSRE_AllTemp.append(NextSRE_All[i][j])
RMSRENext = round((np.mean(NextSRE_AllTemp))**0.5,3)
print(RMSRENext)
# Out:
# 5.3645840369426245e+22

# %%
# print errors:

print('\nError of m is: ' + str(RMSREm))
print('\nError of Nint is: ' + str(RMSRENint))
# Out:
# Error of m is: 0.239
#
# Error of Nint is: 0.273

# %%
# Model after excluding treatments 2000/1/168 and 200/5/168

# %%
# model simulations and measured data for the different treatments - fix problem with time (x axis) in 1000/1/168
miu = 0.04
dNextoutdt = 0.03

TModAll = [] # Each sub-array has the time steps of a specific treatment (periods)
mExpAllTimes,NintExpAllTimes,NextExpAllTimes = [],[],[]
mModAll,NintModAll,NextModAll = [],[],[]

Treatments = ['1000/1/168','500/2/168','500/3/168']#,'2000/1/168','200/5/168']

Temp = 22
#I0 = 80
S = 39 # fix salinity function and S=40

for i in Treatments:
    print('\nTreatment: ' + str(i))
    df2Temp = df2_Reduced[(df2_Reduced.Treatment == i)]
    mTemp = df2Temp[(np.isnan(df2Temp.DW) != True)]['DW']
    mTimeTemp = df2Temp[(np.isnan(df2Temp.DW) != True)]['T']
    NintTemp = df2Temp[(np.isnan(df2Temp.N) != True)]['N']
    NintTimeTemp = df2Temp[(np.isnan(df2Temp.N) != True)]['T']
    NextTemp = df2Temp[(np.isnan(df2Temp.NH4) != True)]['NH4']
    NextTimeTemp = df2Temp[(np.isnan(df2Temp.NH4) != True)]['T']
    mTemp = df2Temp[(~np.isnan(df2Temp.DW))]['DW']
    mTimeTemp = df2Temp[(~np.isnan(df2Temp.DW))]['T']
    NintTemp = df2Temp[(~np.isnan(df2Temp.N))]['N']
    NintTimeTemp = df2Temp[(~np.isnan(df2Temp.N))]['T']
    NextTemp = df2Temp[(~np.isnan(df2Temp.NH4))]['NH4']
    NextTimeTemp = df2Temp[(~np.isnan(df2Temp.NH4))]['T']
    print('Number of samples:\nm: ' + str(len(mTimeTemp)) + ' Nint: ' + str(len(NintTimeTemp)) + ' Next: ' + str(len(NextTimeTemp)))
    
    Tr = []
    Tr = i.split('/')
    Tr = [float(i) for i in Tr]
    Amplitude = Tr[0]
    Period = float(7/Tr[1]) # Period is in hours
    print(Period)
    Duration = Tr[2]/24
    
    NEXT, NINT, M, TT = [],[],[],[]

    n_days = Duration*3
    count_periods = 0
    
    #T1 = '2019,02,14,17,0'
    #T2 = df3Temp['Timei']
    #T2 = T2.tolist()[0]
    #t0 = Time_to_Hours(T1,T2)
    
    # hour = 0 is 1pm (Meiron)
    # in the indoor settings we have to solve for shorter periods, 
    # at the beginning of the Treatment we reset Nint, Next, m
    # at the beginning of each Period we set Next to the last Amplitude, 
    # m0 to the end of previous solution of ode()
    # 
    
    # Let's prepare the IO(t) function that will be supplied to odeint 
    # instead of a scalar. 
    
    all_treatment_hours = np.arange(0,n_days*24,dtype=np.int)
    
    # 8pm on the first day is zero crossing of this one 8pm - 10m = 7 hours
    offtimes = all_treatment_hours[np.mod(all_treatment_hours - 7,24) == 0]
    offtimes = np.r_[offtimes,all_treatment_hours[-1]+1] # last hour would be whatever
    
    # 6am on the next day is zero crossing of this one, 6am - 8pm is 10 hours
    ontimes = all_treatment_hours[np.mod(all_treatment_hours - 7 + 10,24) == 0]
    # and the iniital hour as we always start at 1pm, during ontime
    ontimes = np.r_[np.int(0),ontimes]
    
    # prepare the duty cycle
    I0set = np.zeros_like(all_treatment_hours)
    for s,e in zip(ontimes,offtimes):
        I0set[s:e] = 80
        
    # if you want to replace it by a "constant" I0 then replace the lines above with
    # the following line and then it will also give you a constant solution you had before
    
    # I0set = np.ones_like(all_treatment_hours)*80

    
    
    I0 = interpolate.interp1d(all_treatment_hours, I0set, bounds_error=False, fill_value="extrapolate")
    
    
    
 
    for hour in np.arange(0,n_days*24,round(Period*24,0)):
        print(hour)
        if hour == 0:
            print('Starting point')
            Nint_0 = Nint0
            m_0 = m0
            Next_0 = Amplitude
        
        if hour > 0 and np.mod(hour,round(Period*24,0)) == 0:
            count_periods = count_periods + 1
            
            if count_periods == Tr[1]:
                print('Duration')
                # reset everything, except Nint
                Nint_0 = NINT[-1][-1]
                Next_0 = Amplitude
                m_0 = m0
                count_periods = 0
            else:
                # period passed, not Duration
                # add amplitude, keep going 
                print('Period')
                Next_0 = NEXT[-1][-1] + Amplitude
                Nint_0 = NINT[-1][-1]
                m_0 = M[-1][-1]
   
                
        # Here we want to send odeint the times of the light sub-period or 
        # darkness sub-period

        x0 = [Next_0,Nint_0,m_0]
        # t = np.linspace(hour,hour+Period*24) # every time we solve ODE for 24 hours * Period
        t = np.arange(hour, hour+Period*24) # can also ask for report on round hours

        x = odeint(controlled_N_new,x0,t,args=(Nintmax,Nintmin,Vmax,Ks,dNextoutdt,dNextindt,miu,dmoutdt,Nintcrit,S,Z,KI,K0,Ka,
                                               Topt,Tmin,Tmax,losses20,teta,Sopt,Smin,Smax,n,umol_to_percent_DW,Temp,I0),printmessg=0,hmax=.1)

        NEXT.append(x[: , 0])
        NINT.append(x[: , 1])
        M.append(x[: , 2])
        TT.append(t)
        
        t_model = np.hstack(TT)
        Next_model = np.hstack(NEXT)
        Nint_model = np.hstack(NINT)
        m_model = np.hstack(M)
    
    TModAll.append(TT)
    mExpAllTimes.append(mTimeTemp)
    NintExpAllTimes.append(NintTimeTemp)
    NextExpAllTimes.append(NextTimeTemp)
    
    mModAll.append(m_model)
    NintModAll.append(Nint_model)
    NextModAll.append(Next_model)

    plot_result(t_model,Next_model,Nint_model,m_model,Nint=NintTemp,tNint=NintTimeTemp,m=mTemp,tm=mTimeTemp,Next=NextTemp,tNext=NextTimeTemp)
# Out:
# Treatment: 1000/1/168
# Number of samples:
# m: 50 Nint: 42 Next: 39
# 7.0
# 0.0
# Starting point
# 168.0
# Duration
# 336.0
# Duration
#
# Treatment: 500/2/168
# Number of samples:
# m: 86 Nint: 54 Next: 115
# 3.5
# 0.0
# Starting point
# 84.0
# Period
# 168.0
# Duration
# 252.0
# Period
# 336.0
# Duration
# 420.0
# Period
#
# Treatment: 500/3/168
# Number of samples:
# m: 24 Nint: 18 Next: 22
# 2.3333333333333335
# 0.0
# Starting point
# 56.0
# Period
# 112.0
# Period
# 168.0
# Duration
# 224.0
# Period
# 280.0
# Period
# 336.0
# Duration
# 392.0
# Period
# 448.0
# Period

# %%
# This cell adjusts measurment time to model durations - so that maximum biomass measurements are compared to maximum biomass
# predictions and not to the initial stocking density (m0)

TModTemp = []
TModAllOrg = []
mModReducedAll, NintModReducedAll, NextModReducedAll = [],[],[]
for i in range(len(TModAll)): # loops over 5 treatments
    print(i)
    for j in range(len(TModAll[i])): # Loops over periods in each treatment
        Ttemp = TModAll[i][j]
        for k in Ttemp: #The model ends at 504 hours, but some measurement reach also 50 hours. This sets a 504 hour limit
            if k > 504:
                k = 504
            TModTemp.append(k)
    TModAllOrg.append(TModTemp)
    TModTemp = []

for i in range(len(TModAll)):
    gm = interpolate.interp1d(TModAllOrg[i], mModAll[i],kind = 'linear')
    mModReduced = []
    for j in mExpAllTimes[i]:
        #print(mExpAllTimes[i])
        if j >= 168 and j < 180:
            j = 167.9
        elif j >= 336 and j < 345:
            j = 335.9
        elif j > 504:
            j = 504
        #print(j)
        mModReduced.append(gm(j-1))
    
    mModReducedAll.append(mModReduced)
    gNint = interpolate.interp1d(TModAllOrg[i], NintModAll[i],kind = 'linear')
    NintModReduced = []
    for j in NintExpAllTimes[i]:
        if j >= 168 and j < 180:
            j = 167.9
        if j >= 336 and j < 345:
            j = 335.9
        if j > 504:
            j = 504
        NintModReduced.append(gNint(j-1))
    NintModReducedAll.append(NintModReduced)
    gNext = interpolate.interp1d(TModAllOrg[i], NextModAll[i],kind = 'linear')    
    NextModReduced = []
    for j in NextExpAllTimes[i]:
        if j >= 168 and j < 180:
            j = 167.9
        if j >= 336 and j < 345:
            j = 335.9
        if j > 504:
            j = 504
        NextModReduced.append(gNext(j-1))
    NextModReducedAll.append(NextModReduced)
# Out:
# 0
# 1
# 2

# %%
df2m = df2_Reduced[(np.isnan(df2_Reduced.DW) != True) & (df2_Reduced.Treatment == i)]

# %%
mSRE_All,NintSRE_All,NextSRE_All = [],[],[]
for i in range(len(Treatments)):
    mSRE,NintSRE,NextSRE = [],[],[]
    
    df2m = df2_Reduced[(np.isnan(df2_Reduced.DW) != True)&(df2_Reduced.Treatment == Treatments[i])]
    print('Treatment: ' + str(Treatments[i]) + '\n\nm\n')
    print('Number of samples: ' + str(len(df2m.Sample)) + '\n')
    k = 0
    for j in df2m.Sample:
        mexp = df2m.DW
        mmod = mModReducedAll[i]
        mSRE.append(((mexp.iloc[k]-mmod[k])/mmod[k])**2)
        print('Sample #' + str(math.floor(float(j))))
        print('Measured biomass: ' + str(round(mexp.iloc[k],3)))
        print('Modeled biomass: ' + str(round(float(mmod[k]),3)) + '\n')
        k = k + 1
    RMSREm = round((np.mean(mSRE))**0.5,3)
    mSRE_All.append(mSRE)
    print('The RMSRE of m in treamtment ' + str(Treatments[i]) + ' is: ' + str(RMSREm) + '\n')
    print('end of treatment ' + str(Treatments[i]) + '\n')
    
    df2Nint = df2_Reduced[(np.isnan(df2_Reduced.N) != True)][(df2_Reduced.Treatment == Treatments[i])]
    print('\nNint\n')
    print('Number of samples: ' + str(len(df2Nint.Sample)) + '\n')
    k = 0
    for j in df2Nint.Sample:
        Nintexp = df2Nint.N
        Nintmod = NintModReducedAll[i]
        NintSRE.append(((Nintexp.iloc[k]-Nintmod[k])/Nintmod[k])**2)
        print('Sample #' + str(math.floor(float(j))))
        print('Measured Nint: ' + str(round(float(Nintexp.iloc[k]),3)))     
        print('Modeled Nint: ' + str(round(float(Nintmod[k]),3)) + '\n')        
        k = k + 1
    RMSRENint = round((np.mean(NintSRE))**0.5,3)
    NintSRE_All.append(NintSRE)
    print('\nThe RMSRE of Nint in treamtment ' + str(Treatments[i]) + ' is: ' + str(RMSRENint) + '\n')
    
    df2Next = df2_Reduced[(np.isnan(df2_Reduced.NH4) != True)&(df2_Reduced.Treatment == Treatments[i])]
    #print('\nNext\n')
    #print('Number of samples: ' + str(len(df2Next.Sample)) + '\n')
    k = 0
    for j in df2Next.Sample:
        Nextexp = df2Next.NH4
        if Nextexp.iloc[k] < 0:
            Nextexp.iloc[k] = 0
        Nextmod = NextModReducedAll[i]
        NextSRE.append(((Nextexp.iloc[k]-Nextmod[k])/Nextmod[k])**2)
        #print('Sample #' + str(math.floor(float(j))))
        #print('Measured Next: ' + str(round(float(Nextexp.iloc[k]),3)))     
        #print('Modeled Next: ' + str(round(float(Nextmod[k]),3)) + '\n')        
        k = k + 1
    RMSRENext = round((np.mean(NextSRE))**0.5,3)
    NextSRE_All.append(NextSRE)
    #print('\nThe RMSRE of Next in treamtment ' + str(Treatments[i]) + ' is: ' + str(RMSRENext) + '\n')
print('End of treatment ' + str(Treatments[i]) + '\n')
# Out:
# Treatment: 1000/1/168
#
# m
#
# Number of samples: 50
#
# Sample #1
# Measured biomass: 0.408
# Modeled biomass: 0.437
#
# Sample #2
# Measured biomass: 0.426
# Modeled biomass: 0.437
#
# Sample #3
# Measured biomass: 0.33
# Modeled biomass: 0.437
#
# Sample #11
# Measured biomass: 0.294
# Modeled biomass: 0.445
#
# Sample #12
# Measured biomass: 0.213
# Modeled biomass: 0.445
#
# Sample #13
# Measured biomass: 0.228
# Modeled biomass: 0.445
#
# Sample #21
# Measured biomass: 0.267
# Modeled biomass: 0.445
#
# Sample #22
# Measured biomass: 0.174
# Modeled biomass: 0.445
#
# Sample #23
# Measured biomass: 0.228
# Modeled biomass: 0.445
#
# Sample #31
# Measured biomass: 0.423
# Modeled biomass: 0.44
#
# Sample #32
# Measured biomass: 0.387
# Modeled biomass: 0.44
#
# Sample #33
# Measured biomass: 0.456
# Modeled biomass: 0.44
#
# Sample #41
# Measured biomass: 0.231
# Modeled biomass: 0.44
#
# Sample #42
# Measured biomass: 0.228
# Modeled biomass: 0.44
#
# Sample #51
# Measured biomass: 0.27
# Modeled biomass: 0.437
#
# Sample #52
# Measured biomass: 0.231
# Modeled biomass: 0.437
#
# Sample #53
# Measured biomass: 0.195
# Modeled biomass: 0.437
#
# Sample #91
# Measured biomass: 0.201
# Modeled biomass: 0.248
#
# Sample #91
# Measured biomass: 0.261
# Modeled biomass: 0.349
#
# Sample #92
# Measured biomass: 0.225
# Modeled biomass: 0.248
#
# Sample #92
# Measured biomass: 0.276
# Modeled biomass: 0.349
#
# Sample #93
# Measured biomass: 0.195
# Modeled biomass: 0.248
#
# Sample #93
# Measured biomass: 0.204
# Modeled biomass: 0.349
#
# Sample #91
# Measured biomass: 0.336
# Modeled biomass: 0.45
#
# Sample #92
# Measured biomass: 0.348
# Modeled biomass: 0.45
#
# Sample #93
# Measured biomass: 0.234
# Modeled biomass: 0.45
#
# Sample #101
# Measured biomass: 0.246
# Modeled biomass: 0.241
#
# Sample #101
# Measured biomass: 0.327
# Modeled biomass: 0.344
#
# Sample #102
# Measured biomass: 0.3
# Modeled biomass: 0.241
#
# Sample #102
# Measured biomass: 0.42
# Modeled biomass: 0.344
#
# Sample #103
# Measured biomass: 0.273
# Modeled biomass: 0.241
#
# Sample #103
# Measured biomass: 0.378
# Modeled biomass: 0.344
#
# Sample #101
# Measured biomass: 0.423
# Modeled biomass: 0.445
#
# Sample #102
# Measured biomass: 0.474
# Modeled biomass: 0.445
#
# Sample #103
# Measured biomass: 0.441
# Modeled biomass: 0.445
#
# Sample #111
# Measured biomass: 0.288
# Modeled biomass: 0.248
#
# Sample #111
# Measured biomass: 0.357
# Modeled biomass: 0.331
#
# Sample #112
# Measured biomass: 0.309
# Modeled biomass: 0.248
#
# Sample #112
# Measured biomass: 0.423
# Modeled biomass: 0.331
#
# Sample #113
# Measured biomass: 0.312
# Modeled biomass: 0.248
#
# Sample #113
# Measured biomass: 0.432
# Modeled biomass: 0.331
#
# Sample #111
# Measured biomass: 0.447
# Modeled biomass: 0.451
#
# Sample #112
# Measured biomass: 0.504
# Modeled biomass: 0.451
#
# Sample #113
# Measured biomass: 0.546
# Modeled biomass: 0.451
#
# Sample #121
# Measured biomass: 0.408
# Modeled biomass: 0.45
#
# Sample #122
# Measured biomass: 0.36
# Modeled biomass: 0.45
#
# Sample #131
# Measured biomass: 0.453
# Modeled biomass: 0.45
#
# Sample #132
# Measured biomass: 0.429
# Modeled biomass: 0.45
#
# Sample #141
# Measured biomass: 0.288
# Modeled biomass: 0.437
#
# Sample #142
# Measured biomass: 0.297
# Modeled biomass: 0.437
#
# The RMSRE of m in treamtment 1000/1/168 is: 0.287
#
# end of treatment 1000/1/168
#
#
# Nint
#
# Number of samples: 42
#
# Sample #1
# Measured Nint: 2.071
# Modeled Nint: 1.605
#
# Sample #2
# Measured Nint: 2.014
# Modeled Nint: 1.605
#
# Sample #3
# Measured Nint: 2.179
# Modeled Nint: 1.605
#
# Sample #11
# Measured Nint: 2.609
# Modeled Nint: 1.511
#
# Sample #12
# Measured Nint: 2.98
# Modeled Nint: 1.511
#
# Sample #13
# Measured Nint: 2.865
# Modeled Nint: 1.511
#
# Sample #21
# Measured Nint: 3.105
# Modeled Nint: 1.5
#
# Sample #22
# Measured Nint: 3.726
# Modeled Nint: 1.5
#
# Sample #23
# Measured Nint: 3.402
# Modeled Nint: 1.5
#
# Sample #31
# Measured Nint: 1.761
# Modeled Nint: 1.591
#
# Sample #32
# Measured Nint: 1.727
# Modeled Nint: 1.591
#
# Sample #33
# Measured Nint: 1.628
# Modeled Nint: 1.591
#
# Sample #41
# Measured Nint: 2.875
# Modeled Nint: 1.532
#
# Sample #42
# Measured Nint: 3.131
# Modeled Nint: 1.532
#
# Sample #51
# Measured Nint: 3.227
# Modeled Nint: 1.534
#
# Sample #52
# Measured Nint: 3.043
# Modeled Nint: 1.534
#
# Sample #53
# Measured Nint: 3.462
# Modeled Nint: 1.534
#
# Sample #91
# Measured Nint: 3.883
# Modeled Nint: 3.043
#
# Sample #91
# Measured Nint: 2.897
# Modeled Nint: 2.074
#
# Sample #92
# Measured Nint: 2.21
# Modeled Nint: 3.043
#
# Sample #92
# Measured Nint: 3.022
# Modeled Nint: 2.074
#
# Sample #91
# Measured Nint: 2.197
# Modeled Nint: 1.548
#
# Sample #92
# Measured Nint: 2.837
# Modeled Nint: 1.548
#
# Sample #93
# Measured Nint: 2.414
# Modeled Nint: 1.548
#
# Sample #101
# Measured Nint: 3.848
# Modeled Nint: 3.019
#
# Sample #101
# Measured Nint: 2.678
# Modeled Nint: 2.03
#
# Sample #102
# Measured Nint: 3.131
# Modeled Nint: 3.019
#
# Sample #102
# Measured Nint: 1.97
# Modeled Nint: 2.03
#
# Sample #101
# Measured Nint: 2.218
# Modeled Nint: 1.511
#
# Sample #102
# Measured Nint: 2.732
# Modeled Nint: 1.511
#
# Sample #103
# Measured Nint: 2.18
# Modeled Nint: 1.511
#
# Sample #111
# Measured Nint: 2.359
# Modeled Nint: 2.102
#
# Sample #112
# Measured Nint: 1.923
# Modeled Nint: 2.91
#
# Sample #111
# Measured Nint: 2.136
# Modeled Nint: 1.478
#
# Sample #112
# Measured Nint: 3.957
# Modeled Nint: 1.478
#
# Sample #113
# Measured Nint: 2.035
# Modeled Nint: 1.478
#
# Sample #121
# Measured Nint: 1.237
# Modeled Nint: 1.548
#
# Sample #122
# Measured Nint: 1.983
# Modeled Nint: 1.548
#
# Sample #131
# Measured Nint: 1.459
# Modeled Nint: 1.491
#
# Sample #132
# Measured Nint: 1.835
# Modeled Nint: 1.491
#
# Sample #141
# Measured Nint: 2.083
# Modeled Nint: 1.534
#
# Sample #142
# Measured Nint: 2.164
# Modeled Nint: 1.534
#
#
# The RMSRE of Nint in treamtment 1000/1/168 is: 0.688
#
# Treatment: 500/2/168
#
# m
#
# Number of samples: 86
#
# Sample #37
# Measured biomass: 0.405
# Modeled biomass: 0.44
#
# Sample #38
# Measured biomass: 0.444
# Modeled biomass: 0.44
#
# Sample #39
# Measured biomass: 0.492
# Modeled biomass: 0.44
#
# Sample #47
# Measured biomass: 0.249
# Modeled biomass: 0.44
#
# Sample #49
# Measured biomass: 0.324
# Modeled biomass: 0.44
#
# Sample #57
# Measured biomass: 0.288
# Modeled biomass: 0.437
#
# Sample #58
# Measured biomass: 0.27
# Modeled biomass: 0.437
#
# Sample #59
# Measured biomass: 0.243
# Modeled biomass: 0.437
#
# Sample #61
# Measured biomass: 0.165
# Modeled biomass: 0.181
#
# Sample #61
# Measured biomass: 0.18
# Modeled biomass: 0.203
#
# Sample #61
# Measured biomass: 0.225
# Modeled biomass: 0.241
#
# Sample #61
# Measured biomass: 0.36
# Modeled biomass: 0.382
#
# Sample #62
# Measured biomass: 0.204
# Modeled biomass: 0.203
#
# Sample #62
# Measured biomass: 0.375
# Modeled biomass: 0.382
#
# Sample #63
# Measured biomass: 0.252
# Modeled biomass: 0.241
#
# Sample #64
# Measured biomass: 0.33
# Modeled biomass: 0.382
#
# Sample #61
# Measured biomass: 0.381
# Modeled biomass: 0.45
#
# Sample #62
# Measured biomass: 0.393
# Modeled biomass: 0.45
#
# Sample #63
# Measured biomass: 0.342
# Modeled biomass: 0.45
#
# Sample #64
# Measured biomass: 0.414
# Modeled biomass: 0.45
#
# Sample #65
# Measured biomass: 0.327
# Modeled biomass: 0.45
#
# Sample #66
# Measured biomass: 0.402
# Modeled biomass: 0.45
#
# Sample #67
# Measured biomass: 0.402
# Modeled biomass: 0.45
#
# Sample #68
# Measured biomass: 0.477
# Modeled biomass: 0.45
#
# Sample #69
# Measured biomass: 0.306
# Modeled biomass: 0.45
#
# Sample #71
# Measured biomass: 0.159
# Modeled biomass: 0.181
#
# Sample #71
# Measured biomass: 0.177
# Modeled biomass: 0.203
#
# Sample #71
# Measured biomass: 0.24
# Modeled biomass: 0.248
#
# Sample #71
# Measured biomass: 0.345
# Modeled biomass: 0.401
#
# Sample #72
# Measured biomass: 0.195
# Modeled biomass: 0.203
#
# Sample #72
# Measured biomass: 0.336
# Modeled biomass: 0.401
#
# Sample #73
# Measured biomass: 0.276
# Modeled biomass: 0.248
#
# Sample #74
# Measured biomass: 0.258
# Modeled biomass: 0.248
#
# Sample #75
# Measured biomass: 0.18
# Modeled biomass: 0.181
#
# Sample #75
# Measured biomass: 0.198
# Modeled biomass: 0.203
#
# Sample #75
# Measured biomass: 0.261
# Modeled biomass: 0.248
#
# Sample #75
# Measured biomass: 0.318
# Modeled biomass: 0.401
#
# Sample #76
# Measured biomass: 0.27
# Modeled biomass: 0.248
#
# Sample #71
# Measured biomass: 0.357
# Modeled biomass: 0.45
#
# Sample #72
# Measured biomass: 0.342
# Modeled biomass: 0.45
#
# Sample #73
# Measured biomass: 0.354
# Modeled biomass: 0.45
#
# Sample #74
# Measured biomass: 0.345
# Modeled biomass: 0.45
#
# Sample #75
# Measured biomass: 0.321
# Modeled biomass: 0.45
#
# Sample #76
# Measured biomass: 0.444
# Modeled biomass: 0.45
#
# Sample #77
# Measured biomass: 0.687
# Modeled biomass: 0.45
#
# Sample #78
# Measured biomass: 0.66
# Modeled biomass: 0.45
#
# Sample #79
# Measured biomass: 0.45
# Modeled biomass: 0.45
#
# Sample #81
# Measured biomass: 0.177
# Modeled biomass: 0.178
#
# Sample #81
# Measured biomass: 0.207
# Modeled biomass: 0.212
#
# Sample #81
# Measured biomass: 0.27
# Modeled biomass: 0.241
#
# Sample #81
# Measured biomass: 0.369
# Modeled biomass: 0.382
#
# Sample #83
# Measured biomass: 0.219
# Modeled biomass: 0.241
#
# Sample #84
# Measured biomass: 0.198
# Modeled biomass: 0.212
#
# Sample #85
# Measured biomass: 0.235
# Modeled biomass: 0.241
#
# Sample #81
# Measured biomass: 0.387
# Modeled biomass: 0.451
#
# Sample #83
# Measured biomass: 0.28
# Modeled biomass: 0.451
#
# Sample #84
# Measured biomass: 0.318
# Modeled biomass: 0.451
#
# Sample #85
# Measured biomass: 0.303
# Modeled biomass: 0.451
#
# Sample #86
# Measured biomass: 0.357
# Modeled biomass: 0.451
#
# Sample #87
# Measured biomass: 0.543
# Modeled biomass: 0.451
#
# Sample #88
# Measured biomass: 0.468
# Modeled biomass: 0.451
#
# Sample #89
# Measured biomass: 0.462
# Modeled biomass: 0.451
#
# Sample #104
# Measured biomass: 0.216
# Modeled biomass: 0.241
#
# Sample #104
# Measured biomass: 0.312
# Modeled biomass: 0.344
#
# Sample #105
# Measured biomass: 0.219
# Modeled biomass: 0.241
#
# Sample #105
# Measured biomass: 0.321
# Modeled biomass: 0.344
#
# Sample #106
# Measured biomass: 0.222
# Modeled biomass: 0.241
#
# Sample #106
# Measured biomass: 0.315
# Modeled biomass: 0.344
#
# Sample #104
# Measured biomass: 0.366
# Modeled biomass: 0.445
#
# Sample #105
# Measured biomass: 0.378
# Modeled biomass: 0.445
#
# Sample #106
# Measured biomass: 0.357
# Modeled biomass: 0.445
#
# Sample #114
# Measured biomass: 0.246
# Modeled biomass: 0.248
#
# Sample #114
# Measured biomass: 0.315
# Modeled biomass: 0.331
#
# Sample #115
# Measured biomass: 0.294
# Modeled biomass: 0.248
#
# Sample #115
# Measured biomass: 0.384
# Modeled biomass: 0.331
#
# Sample #116
# Measured biomass: 0.255
# Modeled biomass: 0.248
#
# Sample #116
# Measured biomass: 0.348
# Modeled biomass: 0.331
#
# Sample #114
# Measured biomass: 0.39
# Modeled biomass: 0.451
#
# Sample #115
# Measured biomass: 0.447
# Modeled biomass: 0.451
#
# Sample #116
# Measured biomass: 0.423
# Modeled biomass: 0.451
#
# Sample #123
# Measured biomass: 0.288
# Modeled biomass: 0.45
#
# Sample #124
# Measured biomass: 0.228
# Modeled biomass: 0.45
#
# Sample #133
# Measured biomass: 0.438
# Modeled biomass: 0.45
#
# Sample #134
# Measured biomass: 0.396
# Modeled biomass: 0.45
#
# Sample #143
# Measured biomass: 0.324
# Modeled biomass: 0.437
#
# Sample #144
# Measured biomass: 0.426
# Modeled biomass: 0.437
#
# The RMSRE of m in treamtment 500/2/168 is: 0.192
#
# end of treatment 500/2/168
#
#
# Nint
#
# Number of samples: 54
#
# Sample #37
# Measured Nint: 1.947
# Modeled Nint: 2.197
#
# Sample #38
# Measured Nint: 1.765
# Modeled Nint: 2.197
#
# Sample #39
# Measured Nint: 1.519
# Modeled Nint: 2.197
#
# Sample #47
# Measured Nint: 2.744
# Modeled Nint: 2.254
#
# Sample #49
# Measured Nint: 2.407
# Modeled Nint: 2.254
#
# Sample #57
# Measured Nint: 2.843
# Modeled Nint: 2.284
#
# Sample #58
# Measured Nint: 3.003
# Modeled Nint: 2.284
#
# Sample #59
# Measured Nint: 3.112
# Modeled Nint: 2.284
#
# Sample #61
# Measured Nint: 3.0
# Modeled Nint: 2.636
#
# Sample #62
# Measured Nint: 2.934
# Modeled Nint: 2.969
#
# Sample #63
# Measured Nint: 2.132
# Modeled Nint: 2.499
#
# Sample #64
# Measured Nint: 2.407
# Modeled Nint: 2.581
#
# Sample #61
# Measured Nint: 2.128
# Modeled Nint: 2.138
#
# Sample #62
# Measured Nint: 2.05
# Modeled Nint: 2.138
#
# Sample #63
# Measured Nint: 2.199
# Modeled Nint: 2.138
#
# Sample #64
# Measured Nint: 2.266
# Modeled Nint: 2.138
#
# Sample #65
# Measured Nint: 2.421
# Modeled Nint: 2.138
#
# Sample #66
# Measured Nint: 2.251
# Modeled Nint: 2.138
#
# Sample #71
# Measured Nint: 2.6
# Modeled Nint: 2.506
#
# Sample #72
# Measured Nint: 2.508
# Modeled Nint: 3.08
#
# Sample #73
# Measured Nint: 2.965
# Modeled Nint: 2.553
#
# Sample #75
# Measured Nint: 3.327
# Modeled Nint: 2.795
#
# Sample #71
# Measured Nint: 2.393
# Modeled Nint: 2.193
#
# Sample #72
# Measured Nint: 2.256
# Modeled Nint: 2.193
#
# Sample #73
# Measured Nint: 2.757
# Modeled Nint: 2.193
#
# Sample #74
# Measured Nint: 2.572
# Modeled Nint: 2.193
#
# Sample #75
# Measured Nint: 2.947
# Modeled Nint: 2.193
#
# Sample #76
# Measured Nint: 2.031
# Modeled Nint: 2.193
#
# Sample #77
# Measured Nint: 1.838
# Modeled Nint: 2.193
#
# Sample #78
# Measured Nint: 2.023
# Modeled Nint: 2.193
#
# Sample #79
# Measured Nint: 3.241
# Modeled Nint: 2.193
#
# Sample #81
# Measured Nint: 2.225
# Modeled Nint: 2.654
#
# Sample #84
# Measured Nint: 2.415
# Modeled Nint: 3.031
#
# Sample #81
# Measured Nint: 2.963
# Modeled Nint: 2.2
#
# Sample #83
# Measured Nint: 2.879
# Modeled Nint: 2.2
#
# Sample #84
# Measured Nint: 2.456
# Modeled Nint: 2.2
#
# Sample #85
# Measured Nint: 2.755
# Modeled Nint: 2.2
#
# Sample #86
# Measured Nint: 2.237
# Modeled Nint: 2.2
#
# Sample #104
# Measured Nint: 2.794
# Modeled Nint: 2.629
#
# Sample #104
# Measured Nint: 2.889
# Modeled Nint: 2.978
#
# Sample #105
# Measured Nint: 2.532
# Modeled Nint: 2.629
#
# Sample #105
# Measured Nint: 2.348
# Modeled Nint: 2.978
#
# Sample #104
# Measured Nint: 2.639
# Modeled Nint: 2.221
#
# Sample #105
# Measured Nint: 2.366
# Modeled Nint: 2.221
#
# Sample #114
# Measured Nint: 2.096
# Modeled Nint: 3.088
#
# Sample #115
# Measured Nint: 2.6
# Modeled Nint: 2.577
#
# Sample #114
# Measured Nint: 2.544
# Modeled Nint: 2.2
#
# Sample #115
# Measured Nint: 3.065
# Modeled Nint: 2.2
#
# Sample #123
# Measured Nint: 2.208
# Modeled Nint: 2.138
#
# Sample #124
# Measured Nint: 2.547
# Modeled Nint: 2.138
#
# Sample #133
# Measured Nint: 2.371
# Modeled Nint: 2.193
#
# Sample #134
# Measured Nint: 3.317
# Modeled Nint: 2.193
#
# Sample #143
# Measured Nint: 2.665
# Modeled Nint: 2.284
#
# Sample #144
# Measured Nint: 2.036
# Modeled Nint: 2.284
#
#
# The RMSRE of Nint in treamtment 500/2/168 is: 0.203
#
# Treatment: 500/3/168
#
# m
#
# Number of samples: 24
#
# Sample #107
# Measured biomass: 0.24
# Modeled biomass: 0.241
#
# Sample #107
# Measured biomass: 0.345
# Modeled biomass: 0.344
#
# Sample #108
# Measured biomass: 0.216
# Modeled biomass: 0.241
#
# Sample #108
# Measured biomass: 0.348
# Modeled biomass: 0.344
#
# Sample #109
# Measured biomass: 0.24
# Modeled biomass: 0.241
#
# Sample #109
# Measured biomass: 0.366
# Modeled biomass: 0.344
#
# Sample #107
# Measured biomass: 0.411
# Modeled biomass: 0.445
#
# Sample #108
# Measured biomass: 0.378
# Modeled biomass: 0.445
#
# Sample #109
# Measured biomass: 0.45
# Modeled biomass: 0.445
#
# Sample #117
# Measured biomass: 0.291
# Modeled biomass: 0.248
#
# Sample #117
# Measured biomass: 0.345
# Modeled biomass: 0.331
#
# Sample #118
# Measured biomass: 0.276
# Modeled biomass: 0.248
#
# Sample #118
# Measured biomass: 0.339
# Modeled biomass: 0.331
#
# Sample #119
# Measured biomass: 0.291
# Modeled biomass: 0.248
#
# Sample #119
# Measured biomass: 0.384
# Modeled biomass: 0.331
#
# Sample #117
# Measured biomass: 0.414
# Modeled biomass: 0.451
#
# Sample #118
# Measured biomass: 0.411
# Modeled biomass: 0.451
#
# Sample #119
# Measured biomass: 0.441
# Modeled biomass: 0.451
#
# Sample #125
# Measured biomass: 0.282
# Modeled biomass: 0.45
#
# Sample #126
# Measured biomass: 0.312
# Modeled biomass: 0.45
#
# Sample #135
# Measured biomass: 0.477
# Modeled biomass: 0.45
#
# Sample #136
# Measured biomass: 0.375
# Modeled biomass: 0.45
#
# Sample #145
# Measured biomass: 0.321
# Modeled biomass: 0.437
#
# Sample #146
# Measured biomass: 0.297
# Modeled biomass: 0.437
#
# The RMSRE of m in treamtment 500/3/168 is: 0.158
#
# end of treatment 500/3/168
#
#
# Nint
#
# Number of samples: 18
#
# Sample #107
# Measured Nint: 3.388
# Modeled Nint: 3.421
#
# Sample #107
# Measured Nint: 2.863
# Modeled Nint: 3.257
#
# Sample #108
# Measured Nint: 4.016
# Modeled Nint: 3.421
#
# Sample #108
# Measured Nint: 3.164
# Modeled Nint: 3.257
#
# Sample #107
# Measured Nint: 3.496
# Modeled Nint: 3.135
#
# Sample #108
# Measured Nint: 1.919
# Modeled Nint: 3.135
#
# Sample #109
# Measured Nint: 3.159
# Modeled Nint: 3.135
#
# Sample #117
# Measured Nint: 3.164
# Modeled Nint: 3.324
#
# Sample #118
# Measured Nint: 3.964
# Modeled Nint: 3.44
#
# Sample #118
# Measured Nint: 3.905
# Modeled Nint: 3.324
#
# Sample #118
# Measured Nint: 3.783
# Modeled Nint: 3.113
#
# Sample #119
# Measured Nint: 3.34
# Modeled Nint: 3.113
#
# Sample #125
# Measured Nint: 2.92
# Modeled Nint: 2.933
#
# Sample #126
# Measured Nint: 3.212
# Modeled Nint: 2.933
#
# Sample #135
# Measured Nint: 2.269
# Modeled Nint: 3.095
#
# Sample #136
# Measured Nint: 3.036
# Modeled Nint: 3.095
#
# Sample #145
# Measured Nint: 3.045
# Modeled Nint: 3.231
#
# Sample #146
# Measured Nint: 3.574
# Modeled Nint: 3.231
#
#
# The RMSRE of Nint in treamtment 500/3/168 is: 0.151
#
# End of treatment 500/3/168
# C:\Users\meiro\Anaconda3new\lib\site-packages\ipykernel_launcher.py:22: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\meiro\Anaconda3new\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\meiro\Anaconda3new\lib\site-packages\ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
mSRE_AllTemp = []
for i in range(len(mSRE_All)):
    for j in range(len(mSRE_All[i])):
        mSRE_AllTemp.append(mSRE_All[i][j])
RMSREm = round((np.mean(mSRE_AllTemp))**0.5,3)
print(RMSREm)
# Out:
# 0.222

# %%
NintSRE_AllTemp = []
for i in range(len(NintSRE_All)):
    for j in range(len(NintSRE_All[i])):
        NintSRE_AllTemp.append(NintSRE_All[i][j])
RMSRENint = round((np.mean(NintSRE_AllTemp))**0.5,3)
print(RMSRENint)
# Out:
# 0.444

# %%
# Vmax test
Vmax
# Out:
# 60.0

# %%
# model simulations and measured data for the different treatments - fix problem with time (x axis) in 1000/1/168
miu = 0.04
dNextoutdt = 0.014
Vmax = 60

TModAll = [] # Each sub-array has the time steps of a specific treatment (periods)
mExpAllTimes,NintExpAllTimes,NextExpAllTimes = [],[],[]
mModAll,NintModAll,NextModAll = [],[],[]

Treatments = ['1000/1/168','500/2/168','500/3/168']#,'2000/1/168','200/5/168']

Temp = 22
#I0 = 80
S = 39 # fix salinity function and S=40

for i in Treatments:
    print('\nTreatment: ' + str(i))
    df2Temp = df2_Reduced[(df2_Reduced.Treatment == i)]
    mTemp = df2Temp[(np.isnan(df2Temp.DW) != True)]['DW']
    mTimeTemp = df2Temp[(np.isnan(df2Temp.DW) != True)]['T']
    NintTemp = df2Temp[(np.isnan(df2Temp.N) != True)]['N']
    NintTimeTemp = df2Temp[(np.isnan(df2Temp.N) != True)]['T']
    NextTemp = df2Temp[(np.isnan(df2Temp.NH4) != True)]['NH4']
    NextTimeTemp = df2Temp[(np.isnan(df2Temp.NH4) != True)]['T']
    mTemp = df2Temp[(~np.isnan(df2Temp.DW))]['DW']
    mTimeTemp = df2Temp[(~np.isnan(df2Temp.DW))]['T']
    NintTemp = df2Temp[(~np.isnan(df2Temp.N))]['N']
    NintTimeTemp = df2Temp[(~np.isnan(df2Temp.N))]['T']
    NextTemp = df2Temp[(~np.isnan(df2Temp.NH4))]['NH4']
    NextTimeTemp = df2Temp[(~np.isnan(df2Temp.NH4))]['T']
    print('Number of samples:\nm: ' + str(len(mTimeTemp)) + ' Nint: ' + str(len(NintTimeTemp)) + ' Next: ' + str(len(NextTimeTemp)))
    
    Tr = []
    Tr = i.split('/')
    Tr = [float(i) for i in Tr]
    Amplitude = Tr[0]
    Period = float(7/Tr[1]) # Period is in hours
    print(Period)
    Duration = Tr[2]/24
    
    NEXT, NINT, M, TT = [],[],[],[]

    n_days = Duration*3
    count_periods = 0
    
    #T1 = '2019,02,14,17,0'
    #T2 = df3Temp['Timei']
    #T2 = T2.tolist()[0]
    #t0 = Time_to_Hours(T1,T2)
    
    # hour = 0 is 1pm (Meiron)
    # in the indoor settings we have to solve for shorter periods, 
    # at the beginning of the Treatment we reset Nint, Next, m
    # at the beginning of each Period we set Next to the last Amplitude, 
    # m0 to the end of previous solution of ode()
    # 
    
    # Let's prepare the IO(t) function that will be supplied to odeint 
    # instead of a scalar. 
    
    all_treatment_hours = np.arange(0,n_days*24,dtype=np.int)
    
    # 8pm on the first day is zero crossing of this one 8pm - 10m = 7 hours
    offtimes = all_treatment_hours[np.mod(all_treatment_hours - 7,24) == 0]
    offtimes = np.r_[offtimes,all_treatment_hours[-1]+1] # last hour would be whatever
    
    # 6am on the next day is zero crossing of this one, 6am - 8pm is 10 hours
    ontimes = all_treatment_hours[np.mod(all_treatment_hours - 7 + 10,24) == 0]
    # and the iniital hour as we always start at 1pm, during ontime
    ontimes = np.r_[np.int(0),ontimes]
    
    # prepare the duty cycle
    I0set = np.zeros_like(all_treatment_hours)
    for s,e in zip(ontimes,offtimes):
        I0set[s:e] = 80
        
    # if you want to replace it by a "constant" I0 then replace the lines above with
    # the following line and then it will also give you a constant solution you had before
    
    # I0set = np.ones_like(all_treatment_hours)*80

    
    
    I0 = interpolate.interp1d(all_treatment_hours, I0set, bounds_error=False, fill_value="extrapolate")
    
    
    
 
    for hour in np.arange(0,n_days*24,round(Period*24,0)):
        print(hour)
        if hour == 0:
            print('Starting point')
            Nint_0 = Nint0
            m_0 = m0
            Next_0 = Amplitude
        
        if hour > 0 and np.mod(hour,round(Period*24,0)) == 0:
            count_periods = count_periods + 1
            
            if count_periods == Tr[1]:
                print('Duration')
                # reset everything, except Nint
                Nint_0 = NINT[-1][-1]
                Next_0 = Amplitude
                m_0 = m0
                count_periods = 0
            else:
                # period passed, not Duration
                # add amplitude, keep going 
                print('Period')
                Next_0 = NEXT[-1][-1] + Amplitude
                Nint_0 = NINT[-1][-1]
                m_0 = M[-1][-1]
   
                
        # Here we want to send odeint the times of the light sub-period or 
        # darkness sub-period

        x0 = [Next_0,Nint_0,m_0]
        # t = np.linspace(hour,hour+Period*24) # every time we solve ODE for 24 hours * Period
        t = np.arange(hour, hour+Period*24) # can also ask for report on round hours

        x = odeint(controlled_N_new,x0,t,args=(Nintmax,Nintmin,Vmax,Ks,dNextoutdt,dNextindt,miu,dmoutdt,Nintcrit,S,Z,KI,K0,Ka,
                                               Topt,Tmin,Tmax,losses20,teta,Sopt,Smin,Smax,n,umol_to_percent_DW,Temp,I0),printmessg=0,hmax=.1)

        NEXT.append(x[: , 0])
        NINT.append(x[: , 1])
        M.append(x[: , 2])
        TT.append(t)
        
        t_model = np.hstack(TT)
        Next_model = np.hstack(NEXT)
        Nint_model = np.hstack(NINT)
        m_model = np.hstack(M)
    
    TModAll.append(TT)
    mExpAllTimes.append(mTimeTemp)
    NintExpAllTimes.append(NintTimeTemp)
    NextExpAllTimes.append(NextTimeTemp)
    
    mModAll.append(m_model)
    NintModAll.append(Nint_model)
    NextModAll.append(Next_model)

    plot_result(t_model,Next_model,Nint_model,m_model,Nint=NintTemp,tNint=NintTimeTemp,m=mTemp,tm=mTimeTemp,Next=NextTemp,tNext=NextTimeTemp)
# Out:
# Treatment: 1000/1/168
# Number of samples:
# m: 50 Nint: 42 Next: 39
# 7.0
# 0.0
# Starting point
# 168.0
# Duration
# 336.0
# Duration
#
# Treatment: 500/2/168
# Number of samples:
# m: 86 Nint: 54 Next: 115
# 3.5
# 0.0
# Starting point
# 84.0
# Period
# 168.0
# Duration
# 252.0
# Period
# 336.0
# Duration
# 420.0
# Period
#
# Treatment: 500/3/168
# Number of samples:
# m: 24 Nint: 18 Next: 22
# 2.3333333333333335
# 0.0
# Starting point
# 56.0
# Period
# 112.0
# Period
# 168.0
# Duration
# 224.0
# Period
# 280.0
# Period
# 336.0
# Duration
# 392.0
# Period
# 448.0
# Period

# %%
# This cell adjusts measurment time to model durations - so that maximum biomass measurements are compared to maximum biomass
# predictions and not to the initial stocking density (m0)

TModTemp = []
TModAllOrg = []
mModReducedAll, NintModReducedAll, NextModReducedAll = [],[],[]
for i in range(len(TModAll)): # loops over 5 treatments
    print(i)
    for j in range(len(TModAll[i])): # Loops over periods in each treatment
        Ttemp = TModAll[i][j]
        for k in Ttemp: #The model ends at 504 hours, but some measurement reach also 50 hours. This sets a 504 hour limit
            if k > 504:
                k = 504
            TModTemp.append(k)
    TModAllOrg.append(TModTemp)
    TModTemp = []

for i in range(len(TModAll)):
    gm = interpolate.interp1d(TModAllOrg[i], mModAll[i],kind = 'linear')
    mModReduced = []
    for j in mExpAllTimes[i]:
        #print(mExpAllTimes[i])
        if j >= 168 and j < 180:
            j = 167.9
        elif j >= 336 and j < 345:
            j = 335.9
        elif j > 504:
            j = 504
        #print(j)
        mModReduced.append(gm(j-1))
    
    mModReducedAll.append(mModReduced)
    gNint = interpolate.interp1d(TModAllOrg[i], NintModAll[i],kind = 'linear')
    NintModReduced = []
    for j in NintExpAllTimes[i]:
        if j >= 168 and j < 180:
            j = 167.9
        if j >= 336 and j < 345:
            j = 335.9
        if j > 504:
            j = 504
        NintModReduced.append(gNint(j-1))
    NintModReducedAll.append(NintModReduced)
    gNext = interpolate.interp1d(TModAllOrg[i], NextModAll[i],kind = 'linear')    
    NextModReduced = []
    for j in NextExpAllTimes[i]:
        if j >= 168 and j < 180:
            j = 167.9
        if j >= 336 and j < 345:
            j = 335.9
        if j > 504:
            j = 504
        NextModReduced.append(gNext(j-1))
    NextModReducedAll.append(NextModReduced)
# Out:
# 0
# 1
# 2

# %%
df2m = df2_Reduced[(np.isnan(df2_Reduced.DW) != True) & (df2_Reduced.Treatment == i)]

# %%
mSRE_All,NintSRE_All,NextSRE_All = [],[],[]
for i in range(len(Treatments)):
    mSRE,NintSRE,NextSRE = [],[],[]
    
    df2m = df2_Reduced[(np.isnan(df2_Reduced.DW) != True)&(df2_Reduced.Treatment == Treatments[i])]
    print('Treatment: ' + str(Treatments[i]) + '\n\nm\n')
    print('Number of samples: ' + str(len(df2m.Sample)) + '\n')
    k = 0
    for j in df2m.Sample:
        mexp = df2m.DW
        mmod = mModReducedAll[i]
        mSRE.append(((mexp.iloc[k]-mmod[k])/mmod[k])**2)
        print('Sample #' + str(math.floor(float(j))))
        print('Measured biomass: ' + str(round(mexp.iloc[k],3)))
        print('Modeled biomass: ' + str(round(float(mmod[k]),3)) + '\n')
        k = k + 1
    RMSREm = round((np.mean(mSRE))**0.5,3)
    mSRE_All.append(mSRE)
    print('The RMSRE of m in treamtment ' + str(Treatments[i]) + ' is: ' + str(RMSREm) + '\n')
    print('end of treatment ' + str(Treatments[i]) + '\n')
    
    df2Nint = df2_Reduced[(np.isnan(df2_Reduced.N) != True)][(df2_Reduced.Treatment == Treatments[i])]
    print('\nNint\n')
    print('Number of samples: ' + str(len(df2Nint.Sample)) + '\n')
    k = 0
    for j in df2Nint.Sample:
        Nintexp = df2Nint.N
        Nintmod = NintModReducedAll[i]
        NintSRE.append(((Nintexp.iloc[k]-Nintmod[k])/Nintmod[k])**2)
        print('Sample #' + str(math.floor(float(j))))
        print('Measured Nint: ' + str(round(float(Nintexp.iloc[k]),3)))     
        print('Modeled Nint: ' + str(round(float(Nintmod[k]),3)) + '\n')        
        k = k + 1
    RMSRENint = round((np.mean(NintSRE))**0.5,3)
    NintSRE_All.append(NintSRE)
    print('\nThe RMSRE of Nint in treamtment ' + str(Treatments[i]) + ' is: ' + str(RMSRENint) + '\n')
    
    df2Next = df2_Reduced[(np.isnan(df2_Reduced.NH4) != True)&(df2_Reduced.Treatment == Treatments[i])]
    #print('\nNext\n')
    #print('Number of samples: ' + str(len(df2Next.Sample)) + '\n')
    k = 0
    for j in df2Next.Sample:
        Nextexp = df2Next.NH4
        if Nextexp.iloc[k] < 0:
            Nextexp.iloc[k] = 0
        Nextmod = NextModReducedAll[i]
        NextSRE.append(((Nextexp.iloc[k]-Nextmod[k])/Nextmod[k])**2)
        #print('Sample #' + str(math.floor(float(j))))
        #print('Measured Next: ' + str(round(float(Nextexp.iloc[k]),3)))     
        #print('Modeled Next: ' + str(round(float(Nextmod[k]),3)) + '\n')        
        k = k + 1
    RMSRENext = round((np.mean(NextSRE))**0.5,3)
    NextSRE_All.append(NextSRE)
    #print('\nThe RMSRE of Next in treamtment ' + str(Treatments[i]) + ' is: ' + str(RMSRENext) + '\n')
print('End of treatment ' + str(Treatments[i]) + '\n')
# Out:
# Treatment: 1000/1/168
#
# m
#
# Number of samples: 50
#
# Sample #1
# Measured biomass: 0.408
# Modeled biomass: 0.437
#
# Sample #2
# Measured biomass: 0.426
# Modeled biomass: 0.437
#
# Sample #3
# Measured biomass: 0.33
# Modeled biomass: 0.437
#
# Sample #11
# Measured biomass: 0.294
# Modeled biomass: 0.445
#
# Sample #12
# Measured biomass: 0.213
# Modeled biomass: 0.445
#
# Sample #13
# Measured biomass: 0.228
# Modeled biomass: 0.445
#
# Sample #21
# Measured biomass: 0.267
# Modeled biomass: 0.445
#
# Sample #22
# Measured biomass: 0.174
# Modeled biomass: 0.445
#
# Sample #23
# Measured biomass: 0.228
# Modeled biomass: 0.445
#
# Sample #31
# Measured biomass: 0.423
# Modeled biomass: 0.44
#
# Sample #32
# Measured biomass: 0.387
# Modeled biomass: 0.44
#
# Sample #33
# Measured biomass: 0.456
# Modeled biomass: 0.44
#
# Sample #41
# Measured biomass: 0.231
# Modeled biomass: 0.44
#
# Sample #42
# Measured biomass: 0.228
# Modeled biomass: 0.44
#
# Sample #51
# Measured biomass: 0.27
# Modeled biomass: 0.437
#
# Sample #52
# Measured biomass: 0.231
# Modeled biomass: 0.437
#
# Sample #53
# Measured biomass: 0.195
# Modeled biomass: 0.437
#
# Sample #91
# Measured biomass: 0.201
# Modeled biomass: 0.248
#
# Sample #91
# Measured biomass: 0.261
# Modeled biomass: 0.349
#
# Sample #92
# Measured biomass: 0.225
# Modeled biomass: 0.248
#
# Sample #92
# Measured biomass: 0.276
# Modeled biomass: 0.349
#
# Sample #93
# Measured biomass: 0.195
# Modeled biomass: 0.248
#
# Sample #93
# Measured biomass: 0.204
# Modeled biomass: 0.349
#
# Sample #91
# Measured biomass: 0.336
# Modeled biomass: 0.45
#
# Sample #92
# Measured biomass: 0.348
# Modeled biomass: 0.45
#
# Sample #93
# Measured biomass: 0.234
# Modeled biomass: 0.45
#
# Sample #101
# Measured biomass: 0.246
# Modeled biomass: 0.241
#
# Sample #101
# Measured biomass: 0.327
# Modeled biomass: 0.344
#
# Sample #102
# Measured biomass: 0.3
# Modeled biomass: 0.241
#
# Sample #102
# Measured biomass: 0.42
# Modeled biomass: 0.344
#
# Sample #103
# Measured biomass: 0.273
# Modeled biomass: 0.241
#
# Sample #103
# Measured biomass: 0.378
# Modeled biomass: 0.344
#
# Sample #101
# Measured biomass: 0.423
# Modeled biomass: 0.445
#
# Sample #102
# Measured biomass: 0.474
# Modeled biomass: 0.445
#
# Sample #103
# Measured biomass: 0.441
# Modeled biomass: 0.445
#
# Sample #111
# Measured biomass: 0.288
# Modeled biomass: 0.248
#
# Sample #111
# Measured biomass: 0.357
# Modeled biomass: 0.331
#
# Sample #112
# Measured biomass: 0.309
# Modeled biomass: 0.248
#
# Sample #112
# Measured biomass: 0.423
# Modeled biomass: 0.331
#
# Sample #113
# Measured biomass: 0.312
# Modeled biomass: 0.248
#
# Sample #113
# Measured biomass: 0.432
# Modeled biomass: 0.331
#
# Sample #111
# Measured biomass: 0.447
# Modeled biomass: 0.451
#
# Sample #112
# Measured biomass: 0.504
# Modeled biomass: 0.451
#
# Sample #113
# Measured biomass: 0.546
# Modeled biomass: 0.451
#
# Sample #121
# Measured biomass: 0.408
# Modeled biomass: 0.45
#
# Sample #122
# Measured biomass: 0.36
# Modeled biomass: 0.45
#
# Sample #131
# Measured biomass: 0.453
# Modeled biomass: 0.45
#
# Sample #132
# Measured biomass: 0.429
# Modeled biomass: 0.45
#
# Sample #141
# Measured biomass: 0.288
# Modeled biomass: 0.437
#
# Sample #142
# Measured biomass: 0.297
# Modeled biomass: 0.437
#
# The RMSRE of m in treamtment 1000/1/168 is: 0.287
#
# end of treatment 1000/1/168
#
#
# Nint
#
# Number of samples: 42
#
# Sample #1
# Measured Nint: 2.071
# Modeled Nint: 2.086
#
# Sample #2
# Measured Nint: 2.014
# Modeled Nint: 2.086
#
# Sample #3
# Measured Nint: 2.179
# Modeled Nint: 2.086
#
# Sample #11
# Measured Nint: 2.609
# Modeled Nint: 2.069
#
# Sample #12
# Measured Nint: 2.98
# Modeled Nint: 2.069
#
# Sample #13
# Measured Nint: 2.865
# Modeled Nint: 2.069
#
# Sample #21
# Measured Nint: 3.105
# Modeled Nint: 2.075
#
# Sample #22
# Measured Nint: 3.726
# Modeled Nint: 2.075
#
# Sample #23
# Measured Nint: 3.402
# Modeled Nint: 2.075
#
# Sample #31
# Measured Nint: 1.761
# Modeled Nint: 2.068
#
# Sample #32
# Measured Nint: 1.727
# Modeled Nint: 2.068
#
# Sample #33
# Measured Nint: 1.628
# Modeled Nint: 2.068
#
# Sample #41
# Measured Nint: 2.875
# Modeled Nint: 2.099
#
# Sample #42
# Measured Nint: 3.131
# Modeled Nint: 2.099
#
# Sample #51
# Measured Nint: 3.227
# Modeled Nint: 2.123
#
# Sample #52
# Measured Nint: 3.043
# Modeled Nint: 2.123
#
# Sample #53
# Measured Nint: 3.462
# Modeled Nint: 2.123
#
# Sample #91
# Measured Nint: 3.883
# Modeled Nint: 3.428
#
# Sample #91
# Measured Nint: 2.897
# Modeled Nint: 2.696
#
# Sample #92
# Measured Nint: 2.21
# Modeled Nint: 3.428
#
# Sample #92
# Measured Nint: 3.022
# Modeled Nint: 2.696
#
# Sample #91
# Measured Nint: 2.197
# Modeled Nint: 2.013
#
# Sample #92
# Measured Nint: 2.837
# Modeled Nint: 2.013
#
# Sample #93
# Measured Nint: 2.414
# Modeled Nint: 2.013
#
# Sample #101
# Measured Nint: 3.848
# Modeled Nint: 3.503
#
# Sample #101
# Measured Nint: 2.678
# Modeled Nint: 2.781
#
# Sample #102
# Measured Nint: 3.131
# Modeled Nint: 3.503
#
# Sample #102
# Measured Nint: 1.97
# Modeled Nint: 2.781
#
# Sample #101
# Measured Nint: 2.218
# Modeled Nint: 2.069
#
# Sample #102
# Measured Nint: 2.732
# Modeled Nint: 2.069
#
# Sample #103
# Measured Nint: 2.18
# Modeled Nint: 2.069
#
# Sample #111
# Measured Nint: 2.359
# Modeled Nint: 2.909
#
# Sample #112
# Measured Nint: 1.923
# Modeled Nint: 3.466
#
# Sample #111
# Measured Nint: 2.136
# Modeled Nint: 2.046
#
# Sample #112
# Measured Nint: 3.957
# Modeled Nint: 2.046
#
# Sample #113
# Measured Nint: 2.035
# Modeled Nint: 2.046
#
# Sample #121
# Measured Nint: 1.237
# Modeled Nint: 2.013
#
# Sample #122
# Measured Nint: 1.983
# Modeled Nint: 2.013
#
# Sample #131
# Measured Nint: 1.459
# Modeled Nint: 2.043
#
# Sample #132
# Measured Nint: 1.835
# Modeled Nint: 2.043
#
# Sample #141
# Measured Nint: 2.083
# Modeled Nint: 2.123
#
# Sample #142
# Measured Nint: 2.164
# Modeled Nint: 2.123
#
#
# The RMSRE of Nint in treamtment 1000/1/168 is: 0.344
#
# Treatment: 500/2/168
#
# m
#
# Number of samples: 86
#
# Sample #37
# Measured biomass: 0.405
# Modeled biomass: 0.44
#
# Sample #38
# Measured biomass: 0.444
# Modeled biomass: 0.44
#
# Sample #39
# Measured biomass: 0.492
# Modeled biomass: 0.44
#
# Sample #47
# Measured biomass: 0.249
# Modeled biomass: 0.44
#
# Sample #49
# Measured biomass: 0.324
# Modeled biomass: 0.44
#
# Sample #57
# Measured biomass: 0.288
# Modeled biomass: 0.437
#
# Sample #58
# Measured biomass: 0.27
# Modeled biomass: 0.437
#
# Sample #59
# Measured biomass: 0.243
# Modeled biomass: 0.437
#
# Sample #61
# Measured biomass: 0.165
# Modeled biomass: 0.181
#
# Sample #61
# Measured biomass: 0.18
# Modeled biomass: 0.203
#
# Sample #61
# Measured biomass: 0.225
# Modeled biomass: 0.241
#
# Sample #61
# Measured biomass: 0.36
# Modeled biomass: 0.382
#
# Sample #62
# Measured biomass: 0.204
# Modeled biomass: 0.203
#
# Sample #62
# Measured biomass: 0.375
# Modeled biomass: 0.382
#
# Sample #63
# Measured biomass: 0.252
# Modeled biomass: 0.241
#
# Sample #64
# Measured biomass: 0.33
# Modeled biomass: 0.382
#
# Sample #61
# Measured biomass: 0.381
# Modeled biomass: 0.45
#
# Sample #62
# Measured biomass: 0.393
# Modeled biomass: 0.45
#
# Sample #63
# Measured biomass: 0.342
# Modeled biomass: 0.45
#
# Sample #64
# Measured biomass: 0.414
# Modeled biomass: 0.45
#
# Sample #65
# Measured biomass: 0.327
# Modeled biomass: 0.45
#
# Sample #66
# Measured biomass: 0.402
# Modeled biomass: 0.45
#
# Sample #67
# Measured biomass: 0.402
# Modeled biomass: 0.45
#
# Sample #68
# Measured biomass: 0.477
# Modeled biomass: 0.45
#
# Sample #69
# Measured biomass: 0.306
# Modeled biomass: 0.45
#
# Sample #71
# Measured biomass: 0.159
# Modeled biomass: 0.181
#
# Sample #71
# Measured biomass: 0.177
# Modeled biomass: 0.203
#
# Sample #71
# Measured biomass: 0.24
# Modeled biomass: 0.248
#
# Sample #71
# Measured biomass: 0.345
# Modeled biomass: 0.401
#
# Sample #72
# Measured biomass: 0.195
# Modeled biomass: 0.203
#
# Sample #72
# Measured biomass: 0.336
# Modeled biomass: 0.401
#
# Sample #73
# Measured biomass: 0.276
# Modeled biomass: 0.248
#
# Sample #74
# Measured biomass: 0.258
# Modeled biomass: 0.248
#
# Sample #75
# Measured biomass: 0.18
# Modeled biomass: 0.181
#
# Sample #75
# Measured biomass: 0.198
# Modeled biomass: 0.203
#
# Sample #75
# Measured biomass: 0.261
# Modeled biomass: 0.248
#
# Sample #75
# Measured biomass: 0.318
# Modeled biomass: 0.401
#
# Sample #76
# Measured biomass: 0.27
# Modeled biomass: 0.248
#
# Sample #71
# Measured biomass: 0.357
# Modeled biomass: 0.45
#
# Sample #72
# Measured biomass: 0.342
# Modeled biomass: 0.45
#
# Sample #73
# Measured biomass: 0.354
# Modeled biomass: 0.45
#
# Sample #74
# Measured biomass: 0.345
# Modeled biomass: 0.45
#
# Sample #75
# Measured biomass: 0.321
# Modeled biomass: 0.45
#
# Sample #76
# Measured biomass: 0.444
# Modeled biomass: 0.45
#
# Sample #77
# Measured biomass: 0.687
# Modeled biomass: 0.45
#
# Sample #78
# Measured biomass: 0.66
# Modeled biomass: 0.45
#
# Sample #79
# Measured biomass: 0.45
# Modeled biomass: 0.45
#
# Sample #81
# Measured biomass: 0.177
# Modeled biomass: 0.178
#
# Sample #81
# Measured biomass: 0.207
# Modeled biomass: 0.212
#
# Sample #81
# Measured biomass: 0.27
# Modeled biomass: 0.241
#
# Sample #81
# Measured biomass: 0.369
# Modeled biomass: 0.382
#
# Sample #83
# Measured biomass: 0.219
# Modeled biomass: 0.241
#
# Sample #84
# Measured biomass: 0.198
# Modeled biomass: 0.212
#
# Sample #85
# Measured biomass: 0.235
# Modeled biomass: 0.241
#
# Sample #81
# Measured biomass: 0.387
# Modeled biomass: 0.451
#
# Sample #83
# Measured biomass: 0.28
# Modeled biomass: 0.451
#
# Sample #84
# Measured biomass: 0.318
# Modeled biomass: 0.451
#
# Sample #85
# Measured biomass: 0.303
# Modeled biomass: 0.451
#
# Sample #86
# Measured biomass: 0.357
# Modeled biomass: 0.451
#
# Sample #87
# Measured biomass: 0.543
# Modeled biomass: 0.451
#
# Sample #88
# Measured biomass: 0.468
# Modeled biomass: 0.451
#
# Sample #89
# Measured biomass: 0.462
# Modeled biomass: 0.451
#
# Sample #104
# Measured biomass: 0.216
# Modeled biomass: 0.241
#
# Sample #104
# Measured biomass: 0.312
# Modeled biomass: 0.344
#
# Sample #105
# Measured biomass: 0.219
# Modeled biomass: 0.241
#
# Sample #105
# Measured biomass: 0.321
# Modeled biomass: 0.344
#
# Sample #106
# Measured biomass: 0.222
# Modeled biomass: 0.241
#
# Sample #106
# Measured biomass: 0.315
# Modeled biomass: 0.344
#
# Sample #104
# Measured biomass: 0.366
# Modeled biomass: 0.445
#
# Sample #105
# Measured biomass: 0.378
# Modeled biomass: 0.445
#
# Sample #106
# Measured biomass: 0.357
# Modeled biomass: 0.445
#
# Sample #114
# Measured biomass: 0.246
# Modeled biomass: 0.248
#
# Sample #114
# Measured biomass: 0.315
# Modeled biomass: 0.331
#
# Sample #115
# Measured biomass: 0.294
# Modeled biomass: 0.248
#
# Sample #115
# Measured biomass: 0.384
# Modeled biomass: 0.331
#
# Sample #116
# Measured biomass: 0.255
# Modeled biomass: 0.248
#
# Sample #116
# Measured biomass: 0.348
# Modeled biomass: 0.331
#
# Sample #114
# Measured biomass: 0.39
# Modeled biomass: 0.451
#
# Sample #115
# Measured biomass: 0.447
# Modeled biomass: 0.451
#
# Sample #116
# Measured biomass: 0.423
# Modeled biomass: 0.451
#
# Sample #123
# Measured biomass: 0.288
# Modeled biomass: 0.45
#
# Sample #124
# Measured biomass: 0.228
# Modeled biomass: 0.45
#
# Sample #133
# Measured biomass: 0.438
# Modeled biomass: 0.45
#
# Sample #134
# Measured biomass: 0.396
# Modeled biomass: 0.45
#
# Sample #143
# Measured biomass: 0.324
# Modeled biomass: 0.437
#
# Sample #144
# Measured biomass: 0.426
# Modeled biomass: 0.437
#
# The RMSRE of m in treamtment 500/2/168 is: 0.192
#
# end of treatment 500/2/168
#
#
# Nint
#
# Number of samples: 54
#
# Sample #37
# Measured Nint: 1.947
# Modeled Nint: 2.635
#
# Sample #38
# Measured Nint: 1.765
# Modeled Nint: 2.635
#
# Sample #39
# Measured Nint: 1.519
# Modeled Nint: 2.635
#
# Sample #47
# Measured Nint: 2.744
# Modeled Nint: 2.784
#
# Sample #49
# Measured Nint: 2.407
# Modeled Nint: 2.784
#
# Sample #57
# Measured Nint: 2.843
# Modeled Nint: 2.838
#
# Sample #58
# Measured Nint: 3.003
# Modeled Nint: 2.838
#
# Sample #59
# Measured Nint: 3.112
# Modeled Nint: 2.838
#
# Sample #61
# Measured Nint: 3.0
# Modeled Nint: 2.647
#
# Sample #62
# Measured Nint: 2.934
# Modeled Nint: 3.096
#
# Sample #63
# Measured Nint: 2.132
# Modeled Nint: 2.967
#
# Sample #64
# Measured Nint: 2.407
# Modeled Nint: 3.095
#
# Sample #61
# Measured Nint: 2.128
# Modeled Nint: 2.564
#
# Sample #62
# Measured Nint: 2.05
# Modeled Nint: 2.564
#
# Sample #63
# Measured Nint: 2.199
# Modeled Nint: 2.564
#
# Sample #64
# Measured Nint: 2.266
# Modeled Nint: 2.564
#
# Sample #65
# Measured Nint: 2.421
# Modeled Nint: 2.564
#
# Sample #66
# Measured Nint: 2.251
# Modeled Nint: 2.564
#
# Sample #71
# Measured Nint: 2.6
# Modeled Nint: 3.096
#
# Sample #72
# Measured Nint: 2.508
# Modeled Nint: 3.333
#
# Sample #73
# Measured Nint: 2.965
# Modeled Nint: 3.205
#
# Sample #75
# Measured Nint: 3.327
# Modeled Nint: 3.042
#
# Sample #71
# Measured Nint: 2.393
# Modeled Nint: 2.709
#
# Sample #72
# Measured Nint: 2.256
# Modeled Nint: 2.709
#
# Sample #73
# Measured Nint: 2.757
# Modeled Nint: 2.709
#
# Sample #74
# Measured Nint: 2.572
# Modeled Nint: 2.709
#
# Sample #75
# Measured Nint: 2.947
# Modeled Nint: 2.709
#
# Sample #76
# Measured Nint: 2.031
# Modeled Nint: 2.709
#
# Sample #77
# Measured Nint: 1.838
# Modeled Nint: 2.709
#
# Sample #78
# Measured Nint: 2.023
# Modeled Nint: 2.709
#
# Sample #79
# Measured Nint: 3.241
# Modeled Nint: 2.709
#
# Sample #81
# Measured Nint: 2.225
# Modeled Nint: 3.363
#
# Sample #84
# Measured Nint: 2.415
# Modeled Nint: 3.369
#
# Sample #81
# Measured Nint: 2.963
# Modeled Nint: 2.734
#
# Sample #83
# Measured Nint: 2.879
# Modeled Nint: 2.734
#
# Sample #84
# Measured Nint: 2.456
# Modeled Nint: 2.734
#
# Sample #85
# Measured Nint: 2.755
# Modeled Nint: 2.734
#
# Sample #86
# Measured Nint: 2.237
# Modeled Nint: 2.734
#
# Sample #104
# Measured Nint: 2.794
# Modeled Nint: 3.299
#
# Sample #104
# Measured Nint: 2.889
# Modeled Nint: 3.394
#
# Sample #105
# Measured Nint: 2.532
# Modeled Nint: 3.299
#
# Sample #105
# Measured Nint: 2.348
# Modeled Nint: 3.394
#
# Sample #104
# Measured Nint: 2.639
# Modeled Nint: 2.744
#
# Sample #105
# Measured Nint: 2.366
# Modeled Nint: 2.744
#
# Sample #114
# Measured Nint: 2.096
# Modeled Nint: 3.479
#
# Sample #115
# Measured Nint: 2.6
# Modeled Nint: 3.269
#
# Sample #114
# Measured Nint: 2.544
# Modeled Nint: 2.734
#
# Sample #115
# Measured Nint: 3.065
# Modeled Nint: 2.734
#
# Sample #123
# Measured Nint: 2.208
# Modeled Nint: 2.564
#
# Sample #124
# Measured Nint: 2.547
# Modeled Nint: 2.564
#
# Sample #133
# Measured Nint: 2.371
# Modeled Nint: 2.709
#
# Sample #134
# Measured Nint: 3.317
# Modeled Nint: 2.709
#
# Sample #143
# Measured Nint: 2.665
# Modeled Nint: 2.838
#
# Sample #144
# Measured Nint: 2.036
# Modeled Nint: 2.838
#
#
# The RMSRE of Nint in treamtment 500/2/168 is: 0.189
#
# Treatment: 500/3/168
#
# m
#
# Number of samples: 24
#
# Sample #107
# Measured biomass: 0.24
# Modeled biomass: 0.241
#
# Sample #107
# Measured biomass: 0.345
# Modeled biomass: 0.344
#
# Sample #108
# Measured biomass: 0.216
# Modeled biomass: 0.241
#
# Sample #108
# Measured biomass: 0.348
# Modeled biomass: 0.344
#
# Sample #109
# Measured biomass: 0.24
# Modeled biomass: 0.241
#
# Sample #109
# Measured biomass: 0.366
# Modeled biomass: 0.344
#
# Sample #107
# Measured biomass: 0.411
# Modeled biomass: 0.445
#
# Sample #108
# Measured biomass: 0.378
# Modeled biomass: 0.445
#
# Sample #109
# Measured biomass: 0.45
# Modeled biomass: 0.445
#
# Sample #117
# Measured biomass: 0.291
# Modeled biomass: 0.248
#
# Sample #117
# Measured biomass: 0.345
# Modeled biomass: 0.331
#
# Sample #118
# Measured biomass: 0.276
# Modeled biomass: 0.248
#
# Sample #118
# Measured biomass: 0.339
# Modeled biomass: 0.331
#
# Sample #119
# Measured biomass: 0.291
# Modeled biomass: 0.248
#
# Sample #119
# Measured biomass: 0.384
# Modeled biomass: 0.331
#
# Sample #117
# Measured biomass: 0.414
# Modeled biomass: 0.451
#
# Sample #118
# Measured biomass: 0.411
# Modeled biomass: 0.451
#
# Sample #119
# Measured biomass: 0.441
# Modeled biomass: 0.451
#
# Sample #125
# Measured biomass: 0.282
# Modeled biomass: 0.45
#
# Sample #126
# Measured biomass: 0.312
# Modeled biomass: 0.45
#
# Sample #135
# Measured biomass: 0.477
# Modeled biomass: 0.45
#
# Sample #136
# Measured biomass: 0.375
# Modeled biomass: 0.45
#
# Sample #145
# Measured biomass: 0.321
# Modeled biomass: 0.437
#
# Sample #146
# Measured biomass: 0.297
# Modeled biomass: 0.437
#
# The RMSRE of m in treamtment 500/3/168 is: 0.158
#
# end of treatment 500/3/168
#
#
# Nint
#
# Number of samples: 18
#
# Sample #107
# Measured Nint: 3.388
# Modeled Nint: 3.756
#
# Sample #107
# Measured Nint: 2.863
# Modeled Nint: 3.742
#
# Sample #108
# Measured Nint: 4.016
# Modeled Nint: 3.756
#
# Sample #108
# Measured Nint: 3.164
# Modeled Nint: 3.742
#
# Sample #107
# Measured Nint: 3.496
# Modeled Nint: 3.784
#
# Sample #108
# Measured Nint: 1.919
# Modeled Nint: 3.784
#
# Sample #109
# Measured Nint: 3.159
# Modeled Nint: 3.784
#
# Sample #117
# Measured Nint: 3.164
# Modeled Nint: 3.84
#
# Sample #118
# Measured Nint: 3.964
# Modeled Nint: 3.746
#
# Sample #118
# Measured Nint: 3.905
# Modeled Nint: 3.84
#
# Sample #118
# Measured Nint: 3.783
# Modeled Nint: 3.753
#
# Sample #119
# Measured Nint: 3.34
# Modeled Nint: 3.753
#
# Sample #125
# Measured Nint: 2.92
# Modeled Nint: 3.529
#
# Sample #126
# Measured Nint: 3.212
# Modeled Nint: 3.529
#
# Sample #135
# Measured Nint: 2.269
# Modeled Nint: 3.737
#
# Sample #136
# Measured Nint: 3.036
# Modeled Nint: 3.737
#
# Sample #145
# Measured Nint: 3.045
# Modeled Nint: 3.884
#
# Sample #146
# Measured Nint: 3.574
# Modeled Nint: 3.884
#
#
# The RMSRE of Nint in treamtment 500/3/168 is: 0.197
#
# End of treatment 500/3/168
# C:\Users\meiro\Anaconda3new\lib\site-packages\ipykernel_launcher.py:22: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\meiro\Anaconda3new\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\meiro\Anaconda3new\lib\site-packages\ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
mSRE_AllTemp = []
for i in range(len(mSRE_All)):
    for j in range(len(mSRE_All[i])):
        mSRE_AllTemp.append(mSRE_All[i][j])
RMSREm = round((np.mean(mSRE_AllTemp))**0.5,3)
print(RMSREm)
# Out:
# 0.222

# %%
NintSRE_AllTemp = []
for i in range(len(NintSRE_All)):
    for j in range(len(NintSRE_All[i])):
        NintSRE_AllTemp.append(NintSRE_All[i][j])
RMSRENint = round((np.mean(NintSRE_AllTemp))**0.5,3)
print(RMSRENint)
# Out:
# 0.258

# %%
# II. Make a filtered array including only times of empiric measurement (remove from array results from times in which data was not measured)
# III. Add relevant columns from df2_temp and the model results to a new df_combined
